# %% [markdown]
# # Correlations between multiple targets for symbols

# %%
from itertools import combinations, chain

from math import ceil

from collections import OrderedDict as odict

import textwrap

from os import environ

import seaborn as sns

# %% [markdown]
# ### Configuration

# %%
# Notebook parameters...

species = environ.get('species') or 'Human'

species
# Out:
# 'Human'

# %%
# pActivity column to use...

pactivity_col = 'pchembl_value'

# %%
# Minimum number of compounds in common for a pair of targets...

pair_threshold = 3

# %%
# ChEMBL connection...

engine = create_engine(open('database.txt').read().strip())

# %%
# Seaborn config...

sns.set()

# %% [markdown]
# ### Load targets

# %%
# Load the ChEMBL target info...

targets = pd.read_pickle('chembl_targets.pkl').query("exclude == 0")

targets.shape
# Out:
# (358, 15)

# %%
HTML(targets.query("species == @species").head().to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>symbol</th>
#       <th>approved_name</th>
#       <th>targets</th>
#       <th>n_target</th>
#       <th>chembl_id</th>
#       <th>target_type</th>
#       <th>pref_name</th>
#       <th>species</th>
#       <th>exclude</th>
#       <th>target_class_0</th>
#       <th>target_class_1</th>
#       <th>n_active_tgt</th>
#       <th>n_total_tgt</th>
#       <th>n_active_ss</th>
#       <th>n_total_ss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ABCB1</td>
#       <td>ATP-binding cassette, sub-family B (MDR/TAP), member 1</td>
#       <td>MDR1;7|MDR1;8|ATP-binding cassette, sub-family B (MDR/TAP), member 1;11</td>
#       <td>1</td>
#       <td>CHEMBL4302</td>
#       <td>SINGLE PROTEIN</td>
#       <td>P-glycoprotein 1</td>
#       <td>Human</td>
#       <td>0</td>
#       <td>Transporter > Primary active transporter</td>
#       <td>Transporter > Primary active transporter</td>
#       <td>784</td>
#       <td>1249</td>
#       <td>784</td>
#       <td>1249</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>ABCB11</td>
#       <td>ATP-binding cassette, sub-family B (MDR/TAP), member 11</td>
#       <td>BSEP;6|BSEP;7|BSEP;8</td>
#       <td>1</td>
#       <td>CHEMBL6020</td>
#       <td>SINGLE PROTEIN</td>
#       <td>Bile salt export pump</td>
#       <td>Human</td>
#       <td>0</td>
#       <td>Transporter > Primary active transporter</td>
#       <td>Transporter > Primary active transporter</td>
#       <td>1</td>
#       <td>16</td>
#       <td>1</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>ABCB4</td>
#       <td>ATP-binding cassette, sub-family B (MDR/TAP), member 4</td>
#       <td>MDR3;7|MDR3;8</td>
#       <td>1</td>
#       <td>CHEMBL1743129</td>
#       <td>SINGLE PROTEIN</td>
#       <td>Multidrug resistance protein 3</td>
#       <td>Human</td>
#       <td>0</td>
#       <td>Transporter > Primary active transporter</td>
#       <td>Transporter > Primary active transporter</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>ABCC2</td>
#       <td>ATP-binding cassette, sub-family C (CFTR/MRP), member 2</td>
#       <td>MRP2;7|MRP2;8|ATP-binding cassette, sub-family C (CFTR/MRP), member 2;11</td>
#       <td>1</td>
#       <td>CHEMBL5748</td>
#       <td>SINGLE PROTEIN</td>
#       <td>Canalicular multispecific organic anion transporter 1</td>
#       <td>Human</td>
#       <td>0</td>
#       <td>Transporter > Primary active transporter</td>
#       <td>Transporter > Primary active transporter</td>
#       <td>5</td>
#       <td>27</td>
#       <td>5</td>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>ABCC3</td>
#       <td>ATP-binding cassette, sub-family C (CFTR/MRP), member 3</td>
#       <td>MRP3;7|MRP3;8</td>
#       <td>1</td>
#       <td>CHEMBL5918</td>
#       <td>SINGLE PROTEIN</td>
#       <td>Canalicular multispecific organic anion transporter 2</td>
#       <td>Human</td>
#       <td>0</td>
#       <td>Transporter > Primary active transporter</td>
#       <td>Transporter > Primary active transporter</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Get pairs of targets for gene symbols
#
# Pairs of targets for each symbol having more than minimm number of distinct parent compounds with pActivities associated with them.

# %%
# %%javascript

# IPython.notebook.kernel.execute("notebook_name = " + "'" + window.document.getElementById("notebook_name").innerHTML + "'");

notebook_name = 'Correlation_Targets' # JavaScript magic above doesn't work with runipy

# %%
cache_file = notebook_name + '_' + species + '.pkl'

cache_file
# Out:
# 'Correlation_Targets_Human.pkl'

# %%
# Retrieve activity data for a list of targets...

def get_data_for_targets(target_chemblids):

    sql = """
    select
        *   
    from
      tt_curve_data_v1 a
    where
      a.target_chemblid in ({})
    """.format(', '.join(":{}".format(n+1) for n in range(len(target_chemblids))))
    
    return pd.read_sql_query(sql, engine, params=target_chemblids)

# %%
if os.path.exists(cache_file): os.remove(cache_file)

# %%
# %%cache $cache_file data_by_symbol means_by_symbol pairs_by_symbol

data_by_symbol, means_by_symbol, pairs_by_symbol = odict(), odict(), odict()
    
symbols = targets.query("species == @species")[['symbol', 'chembl_id']].groupby('symbol').count().query('chembl_id > 1').reset_index()['symbol'].values.tolist()

for symbol in symbols:
    
    logging.info("Starting '{}'...".format(symbol))

    # Get list of ChEMBL targets for the gene symbol...
    
    symbol_targets = targets.query("(species == @species) & (symbol == @symbol)")

    target_chemblids = symbol_targets.chembl_id.values.tolist()

    # Get activity data for these ChEMBL targets, calculate means and unstack so each target is represented by a single column...

    data = get_data_for_targets(target_chemblids)
    
    if not data.shape[0]:
        
        logging.warn("> No data for '{}'.".format(symbol))
        
        continue

    means = data[['target_chemblid', 'parent_cmpd_chemblid', pactivity_col]].groupby(['target_chemblid', 'parent_cmpd_chemblid']).mean().unstack(level=0)

    means.columns = means.columns.droplevel()

    if means.shape[1] == 1:

        logging.warn("> Only one target with data for '{}'.".format(symbol))
        
        continue
        
    # Get all pairs of targets with a number of compounds in common greater than some threshold...
    
    try:
    
        target_pairs = pd.DataFrame(
            ((x, means[x].count(), y, means[y].count(), n, d.corr().iloc[0, 1]) for x, y, n, d in
                ((x, y, d.shape[0], d) for x, y, d in
                    ((x, y, means[[x, y]].dropna(how='any')) for x, y in
                        combinations(means.columns.values, 2)
                    )
                )
            if n > pair_threshold), 
            columns=['target_1', 'n_1', 'target_2', 'n_2', 'n', 'r']).sort(['r', 'n'], ascending=False).reset_index(drop=True)

    except ValueError as e:

        if not e.args[0].startswith('Shape of passed values is (0, 0)'): raise

        logging.warn("> No pairs of target with sufficient compounds in common for '{}'.".format(symbol))
        
        continue

    # Add full names of targets (NB renaming and reordering targets)...

    pref_names = symbol_targets[['chembl_id', 'pref_name']].reset_index(drop=True).set_index('chembl_id')

    target_pairs = target_pairs.merge(pref_names, left_on='target_1', right_index=True).merge(pref_names, left_on='target_2', right_index=True).sort('r', ascending=False)
    
    target_pairs.columns = [x.replace('_x', '_1').replace('_y', '_2') for x in target_pairs.columns.values]
    
    target_pairs = target_pairs[['target_1', 'pref_name_1', 'n_1', 'target_2', 'pref_name_2', 'n_2', 'n', 'r']]
    
    # Done...
    
    data_by_symbol[symbol], means_by_symbol[symbol], pairs_by_symbol[symbol] = data, means, target_pairs
    
    logging.info("...OK.")
    
logging.info("Finished.")
# Out:
# [2015/Aug/12 14:01:10 INFO    ] Starting 'AKT1'...
# [2015/Aug/12 14:01:11 WARNING ] > Only one target with data for 'AKT1'.
# [2015/Aug/12 14:01:11 INFO    ] Starting 'CALCR'...
# [2015/Aug/12 14:01:11 WARNING ] > No pairs of target with sufficient compounds in common for 'CALCR'.
# [2015/Aug/12 14:01:11 INFO    ] Starting 'CALCRL'...
# [2015/Aug/12 14:01:11 INFO    ] ...OK.
# [2015/Aug/12 14:01:11 INFO    ] Starting 'CDK2'...
# [2015/Aug/12 14:01:11 INFO    ] ...OK.
# [2015/Aug/12 14:01:11 INFO    ] Starting 'CDK4'...
# [2015/Aug/12 14:01:11 INFO    ] ...OK.
# [2015/Aug/12 14:01:11 INFO    ] Starting 'CHRNA1'...
# [2015/Aug/12 14:01:11 WARNING ] > No pairs of target with sufficient compounds in common for 'CHRNA1'.
# [2015/Aug/12 14:01:11 INFO    ] Starting 'CHRNA4'...
# [2015/Aug/12 14:01:12 INFO    ] ...OK.
# [2015/Aug/12 14:01:12 INFO    ] Starting 'GRIN1'...
# [2015/Aug/12 14:01:12 INFO    ] ...OK.
# [2015/Aug/12 14:01:12 INFO    ] Starting 'KCNJ11'...
# [2015/Aug/12 14:01:12 WARNING ] > No pairs of target with sufficient compounds in common for 'KCNJ11'.
# [2015/Aug/12 14:01:12 INFO    ] Starting 'KCNQ1'...
# [2015/Aug/12 14:01:12 WARNING ] > No pairs of target with sufficient compounds in common for 'KCNQ1'.
# [2015/Aug/12 14:01:12 INFO    ] Starting 'MTOR'...
# [2015/Aug/12 14:01:12 WARNING ] > Only one target with data for 'MTOR'.
# [2015/Aug/12 14:01:12 INFO    ] Starting 'OPRM1'...
# [2015/Aug/12 14:01:12 WARNING ] > Only one target with data for 'OPRM1'.
# [2015/Aug/12 14:01:12 INFO    ] Starting 'PIK3CA'...
# [2015/Aug/12 14:01:13 INFO    ] ...OK.
# [2015/Aug/12 14:01:13 INFO    ] Starting 'PPARG'...
# [2015/Aug/12 14:01:13 WARNING ] > No pairs of target with sufficient compounds in common for 'PPARG'.
# [2015/Aug/12 14:01:13 INFO    ] Starting 'PRKAA1'...
# [2015/Aug/12 14:01:13 WARNING ] > No pairs of target with sufficient compounds in common for 'PRKAA1'.
# [2015/Aug/12 14:01:13 INFO    ] Starting 'PRKAA2'...
# [2015/Aug/12 14:01:13 WARNING ] > No pairs of target with sufficient compounds in common for 'PRKAA2'.
# [2015/Aug/12 14:01:13 INFO    ] Finished.

# %%
# Symbols having multiple targets with sufficient data for comparison...

[(x, y.shape[0]) for x, y in pairs_by_symbol.items()]
# Out:
# [('CALCRL', 1),
#  ('CDK2', 6),
#  ('CDK4', 3),
#  ('CHRNA4', 3),
#  ('GRIN1', 1),
#  ('PIK3CA', 1)]

# %%
# Show data for each symbol...

# HTML('\n'.join("<h3>{}</h3>\n{}".format(x, data_by_symbol[x].to_html()) for x in sorted(data_by_symbol.keys())))

# %%
# Show pair summary info for each symbol...

HTML('\n'.join("<h3>{}</h3>\n{}".format(x, pairs_by_symbol[x].to_html()) for x in sorted(pairs_by_symbol.keys())))
# Out:
# <h3>CALCRL</h3>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>target_1</th>
#       <th>pref_name_1</th>
#       <th>n_1</th>
#       <th>target_2</th>
#       <th>pref_name_2</th>
#       <th>n_2</th>
#       <th>n</th>
#       <th>r</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>CHEMB
</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>CHEMBL1907589</td>
#       <td>Neuronal acetylcholine receptor; alpha4/beta2</td>
#       <td>844</td>
#       <td>CHEMBL3038461</td>
#       <td>Nicotinic acetylcholine receptor alpha4/beta2/alpha5</td>
#       <td>12</td>
#       <td>5</td>
#       <td>-0.047815</td>
#     </tr>
#   </tbody>
# </table>
# <h3>GRIN1</h3>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>target_1</th>
#       <th>pref_name_1</th>
#       <th>n_1</th>
#       <th>target_2</th>
#       <th>pref_name_2</th>
#       <th>n_2</th>
#       <th>n</th>
#       <th>r</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>CHEMBL1907603</td>
#       <td>Glutamate NMDA receptor; GRIN1/GRIN2B</td>
#       <td>191</td>
#       <td>CHEMBL1907604</td>
#       <td>Glutamate NMDA receptor; GRIN1/GRIN2A</td>
#       <td>79</td>
#       <td>52</td>
#       <td>0.857205</td>
#     </tr>
#   </tbody>
# </table>
# <h3>PIK3CA</h3>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>target_1</th>
#       <th>pref_name_1</th>
#       <th>n_1</th>
#       <th>target_2</th>
#       <th>pref_name_2</th>
#       <th>n_2</th>
#       <th>n</th>
#       <th>r</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>CHEMBL2111367</td>
#       <td>PI3-kinase p110-alpha/p85-alpha</td>
#       <td>131</td>
#       <td>CHEMBL4005</td>
#       <td>PI3-kinase p110-alpha subunit</td>
#       <td>2204</td>
#       <td>19</td>
#       <td>0.793875</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Plot pActivity data for pairs of assays

# %%
# Function to plot pChEMBL values for all pairs of ChEMBL targets for a symbol...

ncol, size = 2, 12

min_xc50, max_xc50 = 3.0, 10.0

def plots_for_symbol(symbol):
    
    target_pairs, target_means = pairs_by_symbol[symbol], means_by_symbol[symbol]

    n_pairs = target_pairs.shape[0]

    nrow = int(ceil(n_pairs / ncol))

    fig, axes = plt.subplots(nrow, ncol, figsize=(size*ncol, size*nrow))
    
    fig.suptitle(symbol, fontsize=20)
    
    if nrow > 1: axes = list(chain.from_iterable(axes))

    for ax in axes[n_pairs:]: ax.axis('off')
        
    for i, rec in target_pairs.iterrows():
        
        axis = axes[i]

        pair_means = target_means[[rec.target_1, rec.target_2]].dropna(how='any')

        axis.scatter(pair_means[rec.target_1], pair_means[rec.target_2])
        
        axis.set_xlim(min_xc50, max_xc50)
        axis.set_ylim(min_xc50, max_xc50)
        axis.set_aspect(1)
        
        axis.set_title("{}  ({}/{})  r = {:.2f}  [n = {}]".format(symbol, i+1, n_pairs, rec.r, rec.n), fontsize=14)
        axis.set_xlabel("{}  [n = {}]\n{}".format(rec.target_1, rec.n_1, rec.pref_name_1), fontsize=14)
        axis.set_ylabel("{}  [n = {}]\n{}".format(rec.target_2, rec.n_2, rec.pref_name_2), fontsize=14)

        axis.plot((min_xc50, max_xc50), (min_xc50, max_xc50), color='r', linestyle='-', linewidth=1)
        axis.plot((5, 5), (min_xc50, max_xc50), color='m', linestyle='--', linewidth=2)
        axis.plot((min_xc50, max_xc50), (5, 5), color='m', linestyle='--', linewidth=2)

# %%
# Generate plots for all symbols...

for symbol in sorted(data_by_symbol.keys()):
                         
    plots_for_symbol(symbol)
