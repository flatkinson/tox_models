# %% [markdown]
# # Load Targets
#
# * Load targets from Excel Workbook
# * Get validated HGNC symbols and corresponding approved names
# * Get list of unique Symbols

# %%
from itertools import combinations, chain

# %% [markdown]
# ### Configuration

# %%
# ChEMBL connection...

engine = create_engine(open('database.txt').read().strip())

# %%
verbose = True

# %% [markdown]
# ### Load targets from Excel Workbook

# %%
input_xlsx = 'Toxicology-associated_targets.xlsx'

# %%
xl = pd.ExcelFile(input_xlsx)

tmp = []

for sheetname in xl.sheet_names:
    
    df = pd.read_excel(input_xlsx, sheetname=sheetname).iloc[:, 0:2]

    df.columns = ['target', 'genes']
    
    df['table'] = re.sub('Table\s+', '', sheetname)

    tmp.append(df)
    
df0 = pd.concat(tmp).reset_index(drop=True)

df0.shape
# Out:
# (294, 3)

# %%
df0
# Out:
#                                                                                    target                    genes table
# 0                                                                  Adenosine receptor A2A                  ADORA2A     1
# 1                                                                 α1A-adrenergic receptor                   ADRA1A     1
# 2                                                                 α2A-adrenergic receptor                   ADRA2A     1
# 3                                                                  β1-adrenergic receptor                    ADRB1     1
# 4                                                                  β2-adrenergic receptor                    ADRB2     1
# 5                                                                    Dopamine receptor D1                     DRD1     1
# 6                                                                    Dopamine receptor D2                     DRD2     1
# 7                                                                   Endothelin receptor A                    EDNRA     1
# 8                                                                   Histamine H1 receptor                     HRH1     1
# 9                                                                   Histamine H2 receptor                     HRH2     1
# 10                                                                 δ-type opioid receptor                    OPRD1     1
# 11                                                                 κ-type opioid receptor                    OPRK1     1
# 12                                                                 μ-type opioid receptor                    OPRM1     1
# 13                                                   Muscarinic acetylcholine receptor M1                    CHRM1     1
# 14                                                   Muscarinic acetylcholine receptor M2                    CHRM2     1
# 15                                                                                 5-HT1B                    HTR1B     1
# 16                                                                                 5-HT2A                    HTR2A     1
# 17                                                                                 5-HT2B                    HTR2B     1
# 18                                                               Vasopressin V1A receptor                   AVPR1A     1
# 19                                                Acetylcholine receptor subunit α1 or α4           CHRNA1, CHRNA4     1
# 20                                         Voltage-gated calcium channel subunit α Cav1.2                  CACNA1C     1
# 21                           Potassium voltage-gated channel, subfamily H member 2 (hERG)                    KCNH2     1
# 22   Potassium voltage-gated channel KQT-like member 1 and minimal potassium channel MinK            KCNQ1 & KCNE1     1
# 23                                          Voltage-gated sodium channel subunit α Nav1.5                    SCN5A     1
# 24                                                                   Acetylcholinesterase                     ACHE     1
# 25                                                                       Cyclooxygenase 2                    PTGS2     1
# 26                                                                    Monoamine oxidase A                     MAOA     1
# 27                                                                   Phosphodiesterase 3A                    PDE3A     1
# 28                                                              Noradrenaline transporter                   SLC6A2     1
# 29                                                                  Serotonin transporter                   SLC6A4     1
# 30                                                                           Adenosine A1                   ADORA1   2.1
# 31                                                                          Adenosine A2A                  ADORA2A   2.1
# 32                                                                           Adenosine A3                   ADORA3   2.1
# 33                                                                         Adrenergic α1A                   ADRA1A   2.1
# 34                                                                         Adrenergic α1B                   ADRA1B   2.1
# 35                                                                         Adrenergic α2A                   ADRA2A   2.1
# 36                                                                         Adrenergic α2B                   ADRA2B   2.1
# 37                                                                         Adrenergic α2C                   ADRA2C   2.1
# 38                                                                          Adrenergic β1                    ADRB1   2.1
# 39                                                                          Adrenergic β2                    ADRB2   2.1
# 40                                                                     Angiotensin II AT1                    AGTR1   2.1
# 41                                                                          Bradykinin B1                   BDKRB1   2.1
# 42                                                                          Bradykinin B2                   BDKRB2   2.1
# 43                                                                                   CGRP                   CALCRL   2.1
# 44                                                                      Ca channel type L                  CACNA1C   2.1
# 45                                                                            Dopamine D1                     DRD1   2.1
# 46                                                                        Endothelin ETa                     EDNRA   2.1
# 47                                                                         Endothelin ETb                    EDNRB   2.1
# 48                                                                           Ghrelin GHSR                     GHSR   2.1
# 49                                                                           Histamine H3                     HRH3   2.1
# 50                                                                          Muscarinic M1                    CHRM1   2.1
# 51                                                                          Muscarinic M2                    CHRM2   2.1
# 52                                                                          Muscarinic M3                    CHRM3   2.1
# 53                                                                          Muscarinic M4                    CHRM4   2.1
# 54                                                                         NE transporter                   SLC6A2   2.1
# 55                                                                Nicotinic acetylcholine                   CHRNA1   2.1
# 56                                                                                 NPY Y1                    NPY1R   2.1
# 57                                                                       K channel (hERG)                    KCNH2   2.1
# 58                                                                        K channel [ATP]                   KCNJ11   2.1
# 59                                                                                 5-HT2B                    HTR2B   2.1
# 60                                                                                  5-HT4                     HTR4   2.1
# 61                                                                    Na channel (site 2)                    SCN5A   2.1
# 62                                                                      Thromboxane A2 TP                   TBXA2R   2.1
# 63                                                                        Vasopressin V1A                   AVPR1A   2.1
# 64                                                                        Vasopressin V1B                   AVPR1B   2.1
# 65                                                                               Thrombin                       F2   2.1
# 66                                                                  Adenosine Transporter                  SLC29A1   2.1
# 67                                                                   Adenosine 3 receptor                   ADORA3   2.2
# 68                                                         Adrenergic α2c receptor (Al2c)                   ADRA2C   2.2
# 69                                                           Nicotinic receptor (central)                   CHRNA1   2.2
# 70                                                             Phosphodiesterase 3 (PDE3)                  PDE3A/B   2.2
# 71                                                                Thromboxane A2 (TBXA2R)                   TBXA2R   2.2
# 72                                                                          Muscarinic M1                    CHRM1   2.2
# 73                                                           Adenosine 2a receptor (Ad2a)                  ADORA2A   2.2
# 74                                                         Adrenergic α1a receptor (Al1a)                   ADRA1A   2.2
# 75                                                                 Adrenergic β2 receptor                    ADRB2   2.2
# 76                                                                                Ghrelin                     GHSR   2.2
# 77                                                                                  MAO-A                     MAOA   2.2
# 78                                                                                    NET                   SLC6A2   2.2
# 79                                                             Adenosine 1 receptor (Ad1)                   ADORA1   2.2
# 80                                                                 Adrenergic β1 receptor                    ADRB1   2.2
# 81                                                        Calcium channel (L type) Cav1.2                  CACNA1C   2.2
# 82                                                                                 Nav1.5                    SCN5A   2.2
# 83                                                                                  KCNQ1                    KCNQ1   2.2
# 84                                                                          Muscarinic M2                    CHRM2   2.2
# 85                                                                               Opioid k                    OPRK1   2.2
# 86                                                                               Opioid d                    OPRD1   2.2
# 87                                                                               Thrombin                       F2   2.2
# 88                                                                                  5HT2b                    HTR2B   2.2
# 89                                                      Adenosine transporter (AdT, ENT1)                  SLC29A1   2.2
# 90                                                                         Adrenergic α2A                   ADRA2A   2.2
# 91                                                            Angiotensin II AT1 receptor                    AGTR1   2.2
# 92                                                                                   5HTT                   SLC6A4   2.2
# 93                                                                          Bradykinin B2                   BDKRB2   2.2
# 94                                                                                  CDK2A                     CDK2   2.2
# 95                                                                Cyclooxygenase 2 (COX2)                    PTGS2   2.2
# 96                                                                                    ETa                    EDNRA   2.2
# 97                                                                           Histamine H2                     HRH2   2.2
# 98                                                                        Neuropeptide Y1                    NPY1R   2.2
# 99                                                                            PKBa (AKT1)                     AKT1   2.2
# 100                                                                       Vasopressin V1a                   AVPR1A   2.2
# 101                                                                               alpha1D                   ADRA1D   2.2
# 102                                                                                 beta3                    ADRB3   2.2
# 103                                                                                   APJ                   APLNR    2.2
# 104                                                                                   ANF                   NPR1/2   2.2
# 105                                                                                 CGRP1                   CALCR    2.2
# 106                                                                                   ETb                    EDNRB   2.2
# 107                                                                              Glucagon                     GCGR   2.2
# 108                                                                                GPR103                    QRFPR   2.2
# 109                                                                                K+ ATP                   KCNJ11   2.2
# 110                                                                                 5-HT4                     HTR4   2.2
# 111                                                                                  eNOS                     NOS3   2.2
# 112                                                                          Urotensin II                   UTS2R    2.2
# 113                                                                                   ERb                     ESR2   2.2
# 114                                                                      5-HT transporter                   SLC6A4     3
# 115                                                                                5-HT2B                    HTR2B     3
# 116                                                                                5-HT2C                    HTR2C     3
# 117                                                                                5-HT4e                     HTR4     3
# 118                                                                                 5-HT7                     HTR7     3
# 119                                                                                   A2B                  ADORA2B     3
# 120                                                                                   ACE                      ACE     3
# 121                                                                  acetylcholinesterase                     ACHE     3
# 122                                                                      adenylyl cyclase                    ADCY5     3
# 123                                                                               alpha1A                   ADRA1A     3
# 124                                                                               alpha2B                   ADRA2B     3
# 125                                                                                    AR                       AR     3
# 126                                                                                   AT1                    AGTR1     3
# 127                                                                       ATPase (Na+/K+)      ATP1A1-4 & ATP1B1-4     3
# 128                                                                                 beta1                    ADRB1     3
# 129                                                               Ca2+ L (diltiazem site)                  CACNA1C     3
# 130                                                                                  COX2                    PTGS2     3
# 131                                                                                    D1                     DRD1     3
# 132                                                                                  D4.4                     DRD4     3
# 133                                                                          delta2 (DOP)                    OPRD1     3
# 134                                                                                 GSK3a                    GSK3A     3
# 135                                                                                    H2                     HRH2     3
# 136                                                                                 hERG                     KCNH2     3
# 137                                                                           kappa (KOP)                    OPRK1     3
# 138                                                                                    M2                    CHRM2     3
# 139                                                                                 MAO-A                     MAOA     3
# 140                                                                             MT3 (ML2)           MTNR1A, MTNR1B     3
# 141                                                                            Na+ site 2                    SCN5A     3
# 142                                                                        NE transporter                   SLC6A2     3
# 143                                                                                 PDE3A                    PDE3A     3
# 144                                                                  tyrosine hydroxylase                       TH     3
# 145                                                                                    UT                    UTS2R     3
# 146                                                                                   INa                    SCN5A     4
# 147                                                                                 ICa,L                  CACNA1C     4
# 148                                                                                 ICa,T          CACNA1G,CACNA1H     4
# 149                                                                                 Ito,f              KCND2,KCND3     4
# 150                                                                                 Ito,s        KCNA4,KCNA7,KCNC4     4
# 151                                                                                  IKur              KCNA5,KCNC1     4
# 152                                                                                   IKr                    KCNH2     4
# 153                                                                                   IKs                    KCNQ1     4
# 154                                                                                   IK1             KCNJ2,KCNJ12     4
# 155                                                                                 IKATP                   KCNJ11     4
# 156                                                                                 IKAch                  KCNJ3/5     4
# 157                                                                                   IKP  KCNK1,KCNK6,KCNK3,KCNK4     4
# 158                                                                                    If                HCN2,HCN4     4
# 159                                                                             RAF1/BRAF                     BRAF     5
# 160                                                                          PI3K (p110α)                   PIK3CA     5
# 161                                                                          PI3K (p110γ)                   PIK3CG     5
# 162                                                                                  PDK1                    PDPK1     5
# 163                                                                          AKT1, 2 or 3                 AKT1/2/3     5
# 164                                                                                  mTOR                     MTOR     5
# 165                                                                                  AMPK                 PRKAA1/2     5
# 166                                                                               GSK3α/β                  GSK3A/B     5
# 167                                                                                  CDKs                   CDK2/4     5
# 168                                                                        Aurora kinases                AURKA/B/C     5
# 169                                                                                  PLKs                     PLK1     5
# 170                                                                                PDGFRs                 PDGFRA/B     5
# 171                                                                                VEGFRs          FLT1, KDR, FLT4     5
# 172                                                                          EGFR (ERBB1)                     EGFR     5
# 173                                                                                 ERBB2                    ERBB2     5
# 174                                                                                   KIT                      KIT     5
# 175                                                                               ABL/ARG                     ABL1     5
# 176                                                                                  JAK2                     JAK2     5
# 177                                                                                   FAK                     PTK2     5
# 178                                                                                  DMPK                     DMPK     5
# 179                                                                                   LTK                      LTK     5
# 180                                                                                  ROCK                  ROCK1/2     5
# 181                                                                                  LKB1                    STK11     5
# 182                                                                                ERK1/2                  MAPK3/1     5
# 183                                                                                  PKCα                    PRKCA     5
# 184                                                                                   PKG                    PRKG1     5
# 185                                                                            PIM Kinase                     PIM1     5
# 186                                                                                CAMKII                   CAMK2A     5
# 187                                                                            GRK2, GRK5             ADRBK1, GRK5     5
# 188                                                                                  ASK1                   MAP3K5     5
# 189                                                                                  NTCP                  SLC10A1     6
# 190                                                                                  BSEP                   ABCB11     6
# 191                                                                                  ASBT                  SLC10A2     6
# 192                                                                             OSTα/OSTβ                 SLC51A/B     6
# 193                                                                                  NTCP                  SLC10A1     7
# 194                                                                                 OATPs      SLCO1A2/1B1/1B3/2B1     7
# 195                                                                                  OCTs                  SLC22A1     7
# 196                                                                                  OATs                SLC22A7/9     7
# 197                                                                                  MRP3                    ABCC3     7
# 198                                                                                  MRP4                    ABCC4     7
# 199                                                                                  MDR1                    ABCB1     7
# 200                                                                                  MDR3                    ABCB4     7
# 201                                                                                  MRP2                    ABCC2     7
# 202                                                                                  BSEP                   ABCB11     7
# 203                                                                                 ABCG5                    ABCG5     7
# 204                                                                                 ABCG8                    ABCG8     7
# 205                                                                                  BCRP                    ABCG2     7
# 206                                                                                   AE2                   SLC4A2     7
# 207                                                                                  ASBT                  SLC10A2     7
# 208                                                                                  FIC1                   ATP8B1     7
# 209                                                                               OATP1B1                  SLCO1B1     8
# 210                                                                               OATP1B3                  SLCO1B3     8
# 211                                                                               OATP1A2                  SLCO1A2     8
# 212                                                                               OATP2B1                  SLCO2B1     8
# 213                                                                                  OCT1                  SLC22A1     8
# 214                                                                                 MATE1                  SLC47A1     8
# 215                                                                               MATE2-K                  SLC47A2     8
# 216                                                                                  MDR1                    ABCB1     8
# 217                                                                                  BCRP                    ABCG2     8
# 218                                                                                  BSEP                   ABCB11     8
# 219                                                                                  MRP2                    ABCC2     8
# 220                                                                                  MRP3                    ABCC3     8
# 221                                                                                  MRP4                    ABCC4     8
# 222                                                                                  MDR3                    ABCB4     8
# 223                                                                                  OAT2                  SLC22A7     8
# 224                                                                                  OAT7                  SLC22A9     8
# 225                                                                                  NTCP                  SLC10A1     8
# 226                                                                                OSTα/β                 SLC51A/B     8
# 227                                                                                  MRP6                    ABCC6     8
# 228                                                                                ENT1/2                SLC29A1/2     8
# 229                                                                                   FXR                    NR1H4     9
# 230                                                                                   SHP                    NR0B2     9
# 231                                                                                   PXR                    NR1I2     9
# 232                                                                                   CAR                    NR1I3     9
# 233                                                                                   VDR                      VDR     9
# 234                                                                                 HNF4α                    HNF4A     9
# 235                                                                                  LRH1                    NR5A2     9
# 236                                                                                 PPARα                    PPARA     9
# 237                                                                                 PPARγ                    PPARG     9
# 238                                                                                  LXRα                    NR1H3     9
# 239                                                                                  LXRβ                    NR1H2     9
# 240                                                                                    GR                    NR3C1     9
# 241                                                                                   AhR                      AHR     9
# 242                                                                                  Nrf2                   NFE2L2     9
# 243                                                                                   ACE                      ACE    10
# 244                                                                               alpha2A                   ADRA2A    10
# 245                                                                                    AR                       AR    10
# 246                                                                       ATPase (Na+/K+)      ATP1A1-4 & ATP1B1-4    10
# 247                                                                                 beta2                    ADRB2    10
# 248                                                                 carbonic anhydrase II                      CA2    10
# 249                                                        constitutive NOS (endothelial)                     NOS3    10
# 250                                                                                  COX2                    PTGS2    10
# 251                                                                                  D4.4                     DRD4    10
# 252                                                                               ERalpha                     ESR1    10
# 253                                                                        ERK2 (P42mapk)                    MAPK1    10
# 254                                                                                   ETB                    EDNRB    10
# 255                                                                                    GR                    NR3C1    10
# 256                                                                                 GSK3a                    GSK3A    10
# 257                                                                                    H2                     HRH2    10
# 258                                                                                 MAO-A                     MAOA    10
# 259                                                                               motilin                     MLNR    10
# 260                                                                            Na+ site 2                    SCN5A    10
# 261                                                                                  NMDA                    GRIN1    10
# 262                                 cytochrome P450, family 1, subfamily A, polypeptide 1                   CYP1A1    11
# 263                                 cytochrome P450, family 1, subfamily A, polypeptide 2                   CYP1A2    11
# 264                                 cytochrome P450, family 2, subfamily A, polypeptide 6                   CYP2A6    11
# 265                                 cytochrome P450, family 2, subfamily B, polypeptide 6                   CYP2B6    11
# 266                                 cytochrome P450, family 2, subfamily C, polypeptide 8                   CYP2C8    11
# 267                                 cytochrome P450, family 2, subfamily C, polypeptide 9                   CYP2C9    11
# 268                                cytochrome P450, family 2, subfamily C, polypeptide 19                  CYP2C19    11
# 269                                 cytochrome P450, family 2, subfamily D, polypeptide 6                   CYP2D6    11
# 270                                 cytochrome P450, family 2, subfamily E, polypeptide 1                   CYP2E1    11
# 271                                 cytochrome P450, family 3, subfamily A, polypeptide 4                   CYP3A4    11
# 272                                 cytochrome P450, family 3, subfamily A, polypeptide 5                   CYP3A5    11
# 273                                                       dihydropyrimidine dehydrogenase                     DPYD    11
# 274                                                          glutathione S-transferase M1                    GSTM1    11
# 275                                                          glutathione S-transferase pi                    GSTP1    11
# 276                                                     glutathione S-transferase theta 1                    GSTT1    11
# 277                                 N-acetyltransferase 1 (arylamine N-acetyltransferase)                     NAT1    11
# 278                                 N-acetyltransferase 2 (arylamine N-acetyltransferase)                     NAT2    11
# 279                   sulfotransferase family, cytosolic, 1A, phenol-preferring, member 1                  SULT1A1    11
# 280                                                        thiopurine S-methyltransferase                     TPMT    11
# 281                                  UDP glucuronosyltransferase 1 family, polypeptide A1                   UGT1A1    11
# 282                                 UDP glucuronosyltransferase 2 family, polypeptide B15                  UGT2B15    11
# 283                                 UDP glucuronosyltransferase 2 family, polypeptide B17                  UGT2B17    11
# 284                                  UDP glucuronosyltransferase 2 family, polypeptide B7                   UGT2B7    11
# 285                                ATP-binding cassette, sub-family B (MDR/TAP), member 1                    ABCB1    11
# 286                               ATP-binding cassette, sub-family C (CFTR/MRP), member 2                    ABCC2    11
# 287                                  ATP-binding cassette, sub-family G (WHITE), member 2                    ABCG2    11
# 288                           solute carrier family 15 (H+/peptide transporter), member 2                  SLC15A2    11
# 289                       solute carrier family 22 (organic cation transporter), member 1                  SLC22A1    11
# 290                       solute carrier family 22 (organic cation transporter), member 2                  SLC22A2    11
# 291                        solute carrier family 22 (organic anion transporter), member 6                  SLC22A6    11
# 292                           solute carrier organic anion transporter family, member 1B1                  SLCO1B1    11
# 293                           solute carrier organic anion transporter family, member 1B3                  SLCO1B3    11

# %%
# Check there are no non-ASCII characters in the gene names...

for gene in df0['genes']:
        
    try:
        
        gene.decode('ascii')
        
    except UnicodeEncodeError as e:
    
        logging.info(u"Input '{}' contains non-ASCII characters".format(gene))

# %% [markdown]
# ### Expand gene names into HGNC symbols
#
# Expand gene names into HGCN symbols, check the validity of these and get the corresponding approved names.

# %%
# Function to expand gene name(s) from original sources into HGNC symbols (NB validation of these symbols is a separate step)...

def get_symbols(gene):    
        
    symbols = []
        
    chunks = re.split(u'\s*[,&]\s*', gene)
    
    for chunk in chunks:
                
        chunk = chunk.replace(' ', '')
        
        is_range = re.search(u'^(\w*)(\d)-(\d)$', chunk)
        
        if is_range:
            
            stem, i, j = is_range.groups()
            
            suffixes = range(int(i), int(j)+1)
            
        else:
            
            suffix_list = re.search(r'^(\w+)/(.+)$', chunk)
        
            if suffix_list:

                first = suffix_list.group(1)

                suffixes = suffix_list.group(2).split('/')

                n = len(suffixes[0]) # NB Assumption is that all suffixes are the same length

                stem, suffix = first[:-n], first[-n:] # Divide first name

                suffixes.insert(0, suffix) 

            else:
                
                suffixes = None
            
        if suffixes:
                    
            symbols.extend("{}{}".format(stem, x) for x in suffixes)
            
        else: # chunk is a symbol
        
            symbols.append(chunk)

    return symbols

# %%
# Convert gene name(s) from original sources into valid HGNC symbols, usings HGNC web service to validate symbols and get their approved name...

cache = {} # Cache of validated HGNC symbols and their approved names

records = []

for n, record in enumerate((dict(x) for _, x in df0.iterrows()), 1):
    
    gene, target = record['genes'], record['target']
    
    symbols = get_symbols(gene)
     
    if verbose: logging.info(u"> {:3d}) target '{}', genes '{}' -> symbols {}".format(n, target, gene, ', '.join("'{}'".format(x) for x in symbols)))
        
    for n_symbol, symbol in enumerate(symbols, 1):
                  
        if symbol not in cache:
        
            results = requests.get("http://rest.genenames.org/fetch/symbol/{}".format(symbol), headers={'accept': 'application/json'}).json()['response']['docs']

            if results:
                
                cache[symbol] = results[0]['name']
                
            else:
            
                logging.warn("Symbol '{}' from gene(s) '{}' for target '{}' in table {} is not recognized by HGNC".format(symbol, gene, target, record['table']))
                
                continue
        
        tmp = record.copy()
        
        tmp.update({'n_symbol': n_symbol, 'symbol': symbol, 'approved_name': cache[symbol]})
                
        records.append(tmp)
                
df1 = pd.DataFrame(records, columns=df0.columns.values.tolist() + ['n_symbol', 'symbol', 'approved_name'])

logging.info("Finished: did {} input records in total.".format(n))
# Out:
# [2015/Jul/07 13:14:45 INFO    ] >   1) target 'Adenosine receptor A2A', genes 'ADORA2A' -> symbols 'ADORA2A'
# [2015/Jul/07 13:14:46 INFO    ] >   2) target 'α1A-adrenergic receptor', genes 'ADRA1A' -> symbols 'ADRA1A'
# [2015/Jul/07 13:14:46 INFO    ] >   3) target 'α2A-adrenergic receptor', genes 'ADRA2A' -> symbols 'ADRA2A'
# [2015/Jul/07 13:14:47 INFO    ] >   4) target 'β1-adrenergic receptor', genes 'ADRB1' -> symbols 'ADRB1'
# [2015/Jul/07 13:14:47 INFO    ] >   5) target 'β2-adrenergic receptor', genes 'ADRB2' -> symbols 'ADRB2'
# [2015/Jul/07 13:14:48 INFO    ] >   6) target 'Dopamine receptor D1', genes 'DRD1' -> symbols 'DRD1'
# [2015/Jul/07 13:14:48 INFO    ] >   7) target 'Dopamine receptor D2', genes 'DRD2' -> symbols 'DRD2'
# [2015/Jul/07 13:14:48 INFO    ] >   8) target 'Endothelin receptor A', genes 'EDNRA' -> symbols 'EDNRA'
# [2015/Jul/07 13:14:49 INFO    ] >   9) target 'Histamine H1 receptor', genes 'HRH1' -> symbols 'HRH1'
# [2015/Jul/07 13:14:49 INFO    ] >  10) target 'Histamine H2 receptor', genes 'HRH2' -> symbols 'HRH2'
# [2015/Jul/07 13:14:51 INFO    ] >  11) target 'δ-type opioid receptor', genes 'OPRD1' -> symbols 'OPRD1'
# [2015/Jul/07 13:14:51 INFO    ] >  12) target 'κ-type opioid receptor', genes 'OPRK1' -> symbols 'OPRK1'
# [2015/Jul/07 13:14:52 INFO    ] >  13) target 'μ-type opioid receptor', genes 'OPRM1' -> symbols 'OPRM1'
# [2015/Jul/07 13:14:52 INFO    ] >  14) target 'Muscarinic acetylcholine receptor M1', genes 'CHRM1' -> symbols 'CHRM1'
# [2015/Jul/07 13:14:52 INFO    ] >  15) target 'Muscarinic acetylcholine receptor M2', genes 'CHRM2' -> symbols 'CHRM2'
# [2015/Jul/07 13:14:53 INFO    ] >  16) target '5-HT1B', genes 'HTR1B' -> symbols 'HTR1B'
# [2015/Jul/07 13:14:53 INFO    ] >  17) target '5-HT2A', genes 'HTR2A' -> symbols 'HTR2A'
# [2015/Jul/07 13:14:54 INFO    ] >  18) target '5-HT2B', genes 'HTR2B' -> symbols 'HTR2B'
# [2015/Jul/07 13:14:54 INFO    ] >  19) target 'Vasopressin V1A receptor', genes 'AVPR1A' -> symbols 'AVPR1A'
# [2015/Jul/07 13:14:54 INFO    ] >  20) target 'Acetylcholine receptor subunit α1 or α4', genes 'CHRNA1, CHRNA4' -> symbols 'CHRNA1', 'CHRNA4'
# [2015/Jul/07 13:14:55 INFO    ] >  21) target 'Voltage-gated calcium channel subunit α Cav1.2', genes 'CACNA1C' -> symbols 'CACNA1C'
# [2015/Jul/07 13:14:56 INFO    ] >  22) target 'Potassium voltage-gated channel, subfamily H member 2 (hERG)', genes 'KCNH2' -> symbols 'KCNH2'
# [2015/Jul/07 13:14:56 INFO    ] >  23) target 'Potassium voltage-gated channel KQT-like member 1 and minimal potassium channel MinK', genes 'KCNQ1 & KCNE1' -> symbols 'KCNQ1', 'KCNE1'
# [2015/Jul/07 13:14:57 INFO    ] >  24) target 'Voltage-gated sodium channel subunit α Nav1.5', genes 'SCN5A' -> symbols 'SCN5A'
# [2015/Jul/07 13:14:57 INFO    ] >  25) target 'Acetylcholinesterase', genes 'ACHE' -> symbols 'ACHE'
# [2015/Jul/07 13:14:58 INFO    ] >  26) target 'Cyclooxygenase 2', genes 'PTGS2' -> symbols 'PTGS2'
# [2015/Jul/07 13:14:58 INFO    ] >  27) target 'Monoamine oxidase A', genes 'MAOA' -> symbols 'MAOA'
# [2015/Jul/07 13:14:59 INFO    ] >  28) target 'Phosphodiesterase 3A', genes 'PDE3A' -> symbols 'PDE3A'
# [2015/Jul/07 13:14:59 INFO    ] >  29) target 'Noradrenaline transporter', genes 'SLC6A2' -> symbols 'SLC6A2'
# [2015/Jul/07 13:15:00 INFO    ] >  30) target 'Serotonin transporter', genes 'SLC6A4' -> symbols 'SLC6A4'
# [2015/Jul/07 13:15:00 INFO    ] >  31) target 'Adenosine A1', genes 'ADORA1' -> symbols 'ADORA1'
# [2015/Jul/07 13:15:00 INFO    ] >  32) target 'Adenosine A2A', genes 'ADORA2A' -> symbols 'ADORA2A'
# [2015/Jul/07 13:15:00 INFO    ] >  33) target 'Adenosine A3', genes 'ADORA3' -> symbols 'ADORA3'
# [2015/Jul/07 13:15:01 INFO    ] >  34) target 'Adrenergic α1A', genes 'ADRA1A' -> symbols 'ADRA1A'
# [2015/Jul/07 13:15:01 INFO    ] >  35) target 'Adrenergic α1B', genes 'ADRA1B' -> symbols 'ADRA1B'
# [2015/Jul/07 13:15:01 INFO    ] >  36) target 'Adrenergic α2A', genes 'ADRA2A' -> symbols 'ADRA2A'
# [2015/Jul/07 13:15:01 INFO    ] >  37) target 'Adrenergic α2B', genes 'ADRA2B' -> symbols 'ADRA2B'
# [2015/Jul/07 13:15:02 INFO    ] >  38) target 'Adrenergic α2C', genes 'ADRA2C' -> symbols 'ADRA2C'
# [2015/Jul/07 13:15:02 INFO    ] >  39) target 'Adrenergic β1', genes 'ADRB1' -> symbols 'ADRB1'
# [2015/Jul/07 13:15:02 INFO    ] >  40) target 'Adrenergic β2', genes 'ADRB2' -> symbols 'ADRB2'
# [2015/Jul/07 13:15:02 INFO    ] >  41) target 'Angiotensin II AT1', genes 'AGTR1' -> symbols 'AGTR1'
# [2015/Jul/07 13:15:03 INFO    ] >  42) target 'Bradykinin B1', genes 'BDKRB1' -> symbols 'BDKRB1'
# [2015/Jul/07 13:15:03 INFO    ] >  43) target 'Bradykinin B2', genes 'BDKRB2' -> symbols 'BDKRB2'
# [2015/Jul/07 13:15:04 INFO    ] >  44) target 'CGRP', genes 'CALCRL' -> symbols 'CALCRL'
# [2015/Jul/07 13:15:04 INFO    ] >  45) target 'Ca channel type L', genes 'CACNA1C' -> symbols 'CACNA1C'
# [2015/Jul/07 13:15:04 INFO    ] >  46) target 'Dopamine D1', genes 'DRD1' -> symbols 'DRD1'
# [2015/Jul/07 13:15:04 INFO    ] >  47) target 'Endothelin ETa ', genes 'EDNRA' -> symbols 'EDNRA'
# [2015/Jul/07 13:15:04 INFO    ] >  48) target 'Endothelin ETb', genes 'EDNRB' -> symbols 'EDNRB'
# [2015/Jul/07 13:15:05 INFO    ] >  49) target 'Ghrelin GHSR', genes 'GHSR' -> symbols 'GHSR'
# [2015/Jul/07 13:15:05 INFO    ] >  50) target 'Histamine H3', genes 'HRH3' -> symbols 'HRH3'
# [2015/Jul/07 13:15:05 INFO    ] >  51) target 'Muscarinic M1', genes 'CHRM1' -> symbols 'CHRM1'
# [2015/Jul/07 13:15:05 INFO    ] >  52) target 'Muscarinic M2', genes 'CHRM2' -> symbols 'CHRM2'
# [2015/Jul/07 13:15:05 INFO    ] >  53) target 'Muscarinic M3', genes 'CHRM3' -> symbols 'CHRM3'
# [2015/Jul/07 13:15:06 INFO    ] >  54) target 'Muscarinic M4', genes 'CHRM4' -> symbols 'CHRM4'
# [2015/Jul/07 13:15:06 INFO    ] >  55) target 'NE transporter', genes 'SLC6A2' -> symbols 'SLC6A2'
# [2015/Jul/07 13:15:06 INFO    ] >  56) target 'Nicotinic acetylcholine', genes 'CHRNA1' -> symbols 'CHRNA1'
# [2015/Jul/07 13:15:06 INFO    ] >  57) target 'NPY Y1', genes 'NPY1R' -> symbols 'NPY1R'
# [2015/Jul/07 13:15:07 INFO    ] >  58) target 'K channel (hERG)', genes 'KCNH2' -> symbols 'KCNH2'
# [2015/Jul/07 13:15:07 INFO    ] >  59) target 'K channel [ATP]', genes 'KCNJ11' -> symbols 'KCNJ11'
# [2015/Jul/07 13:15:07 INFO    ] >  60) target '5-HT2B', genes 'HTR2B' -> symbols 'HTR2B'
# [2015/Jul/07 13:15:07 INFO    ] >  61) target '5-HT4', genes 'HTR4' -> symbols 'HTR4'
# [2015/Jul/07 13:15:08 INFO    ] >  62) target 'Na channel (site 2)', genes 'SCN5A' -> symbols 'SCN5A'
# [2015/Jul/07 13:15:08 INFO    ] >  63) target 'Thromboxane A2 TP', genes 'TBXA2R' -> symbols 'TBXA2R'
# [2015/Jul/07 13:15:08 INFO    ] >  64) target 'Vasopressin V1A', genes 'AVPR1A' -> symbols 'AVPR1A'
# [2015/Jul/07 13:15:08 INFO    ] >  65) target 'Vasopressin V1B', genes 'AVPR1B' -> symbols 'AVPR1B'
# [2015/Jul/07 13:15:09 INFO    ] >  66) target 'Thrombin', genes 'F2' -> symbols 'F2'
# [2015/Jul/07 13:15:09 INFO    ] >  67) target 'Adenosine Transporter', genes 'SLC29A1' -> symbols 'SLC29A1'
# [2015/Jul/07 13:15:10 INFO    ] >  68) target 'Adenosine 3 receptor', genes 'ADORA3' -> symbols 'ADORA3'
# [2015/Jul/07 13:15:10 INFO    ] >  69) target 'Adrenergic α2c receptor (Al2c)', genes 'ADRA2C' -> symbols 'ADRA2C'
# [2015/Jul/07 13:15:10 INFO    ] >  70) target 'Nicotinic receptor (central)', genes 'CHRNA1' -> symbols 'CHRNA1'
# [2015/Jul/07 13:15:10 INFO    ] >  71) target 'Phosphodiesterase 3 (PDE3)', genes 'PDE3A/B' -> symbols 'PDE3A', 'PDE3B'
# [2015/Jul/07 13:15:11 INFO    ] >  72) target 'Thromboxane A2 (TBXA2R)', genes 'TBXA2R' -> symbols 'TBXA2R'
# [2015/Jul/07 13:15:11 INFO    ] >  73) target 'Muscarinic M1', genes 'CHRM1' -> symbols 'CHRM1'
# [2015/Jul/07 13:15:11 INFO    ] >  74) target 'Adenosine 2a receptor (Ad2a)', genes 'ADORA2A' -> symbols 'ADORA2A'
# [2015/Jul/07 13:15:11 INFO    ] >  75) target 'Adrenergic α1a receptor (Al1a)', genes 'ADRA1A' -> symbols 'ADRA1A'
# [2015/Jul/07 13:15:11 INFO    ] >  76) target 'Adrenergic β2 receptor', genes 'ADRB2' -> symbols 'ADRB2'
# [2015/Jul/07 13:15:11 INFO    ] >  77) target 'Ghrelin', genes 'GHSR' -> symbols 'GHSR'
# [2015/Jul/07 13:15:11 INFO    ] >  78) target 'MAO-A', genes 'MAOA' -> symbols 'MAOA'
# [2015/Jul/07 13:15:11 INFO    ] >  79) target 'NET', genes 'SLC6A2' -> symbols 'SLC6A2'
# [2015/Jul/07 13:15:11 INFO    ] >  80) target 'Adenosine 1 receptor (Ad1)', genes 'ADORA1' -> symbols 'ADORA1'
# [2015/Jul/07 13:15:11 INFO    ] >  81) target 'Adrenergic β1 receptor', genes 'ADRB1' -> symbols 'ADRB1'
# [2015/Jul/07 13:15:11 INFO    ] >  82) target 'Calcium channel (L type) Cav1.2', genes 'CACNA1C' -> symbols 'CACNA1C'
# [2015/Jul/07 13:15:11 INFO    ] >  83) target 'Nav1.5', genes 'SCN5A' -> symbols 'SCN5A'
# [2015/Jul/07 13:15:11 INFO    ] >  84) target 'KCNQ1', genes 'KCNQ1' -> symbols 'KCNQ1'
# [2015/Jul/07 13:15:11 INFO    ] >  85) target 'Muscarinic M2', genes 'CHRM2' -> symbols 'CHRM2'
# [2015/Jul/07 13:15:11 INFO    ] >  86) target 'Opioid k', genes 'OPRK1' -> symbols 'OPRK1'
# [2015/Jul/07 13:15:11 INFO    ] >  87) target 'Opioid d', genes 'OPRD1' -> symbols 'OPRD1'
# [2015/Jul/07 13:15:11 INFO    ] >  88) target 'Thrombin', genes 'F2' -> symbols 'F2'
# [2015/Jul/07 13:15:11 INFO    ] >  89) target '5HT2b', genes 'HTR2B' -> symbols 'HTR2B'
# [2015/Jul/07 13:15:11 INFO    ] >  90) target 'Adenosine transporter (AdT, ENT1)', genes 'SLC29A1' -> symbols 'SLC29A1'
# [2015/Jul/07 13:15:11 INFO    ] >  91) target 'Adrenergic α2A', genes 'ADRA2A' -> symbols 'ADRA2A'
# [2015/Jul/07 13:15:11 INFO    ] >  92) target 'Angiotensin II AT1 receptor', genes 'AGTR1' -> symbols 'AGTR1'
# [2015/Jul/07 13:15:11 INFO    ] >  93) target '5HTT', genes 'SLC6A4' -> symbols 'SLC6A4'
# [2015/Jul/07 13:15:11 INFO    ] >  94) target 'Bradykinin B2', genes 'BDKRB2' -> symbols 'BDKRB2'
# [2015/Jul/07 13:15:11 INFO    ] >  95) target 'CDK2A', genes 'CDK2' -> symbols 'CDK2'
# [2015/Jul/07 13:15:11 INFO    ] >  96) target 'Cyclooxygenase 2 (COX2)', genes 'PTGS2' -> symbols 'PTGS2'
# [2015/Jul/07 13:15:11 INFO    ] >  97) target 'ETa', genes 'EDNRA' -> symbols 'EDNRA'
# [2015/Jul/07 13:15:11 INFO    ] >  98) target 'Histamine H2', genes 'HRH2' -> symbols 'HRH2'
# [2015/Jul/07 13:15:11 INFO    ] >  99) target 'Neuropeptide Y1', genes 'NPY1R' -> symbols 'NPY1R'
# [2015/Jul/07 13:15:11 INFO    ] > 100) target 'PKBa (AKT1)', genes 'AKT1' -> symbols 'AKT1'
# [2015/Jul/07 13:15:12 INFO    ] > 101) target 'Vasopressin V1a', genes 'AVPR1A' -> symbols 'AVPR1A'
# [2015/Jul/07 13:15:12 INFO    ] > 102) target 'alpha1D', genes 'ADRA1D' -> symbols 'ADRA1D'
# [2015/Jul/07 13:15:12 INFO    ] > 103) target 'beta3', genes 'ADRB3' -> symbols 'ADRB3'
# [2015/Jul/07 13:15:13 INFO    ] > 104) target 'APJ', genes 'APLNR ' -> symbols 'APLNR'
# [2015/Jul/07 13:15:13 INFO    ] > 105) target 'ANF', genes 'NPR1/2' -> symbols 'NPR1', 'NPR2'
# [2015/Jul/07 13:15:14 INFO    ] > 106) target 'CGRP1', genes 'CALCR ' -> symbols 'CALCR'
# [2015/Jul/07 13:15:15 INFO    ] > 107) target 'ETb', genes 'EDNRB' -> symbols 'EDNRB'
# [2015/Jul/07 13:15:15 INFO    ] > 108) target 'Glucagon', genes 'GCGR' -> symbols 'GCGR'
# [2015/Jul/07 13:15:15 INFO    ] > 109) target 'GPR103', genes 'QRFPR' -> symbols 'QRFPR'
# [2015/Jul/07 13:15:16 INFO    ] > 110) target 'K+ ATP', genes 'KCNJ11' -> symbols 'KCNJ11'
# [2015/Jul/07 13:15:16 INFO    ] > 111) target '5-HT4', genes 'HTR4' -> symbols 'HTR4'
# [2015/Jul/07 13:15:16 INFO    ] > 112) target 'eNOS', genes 'NOS3' -> symbols 'NOS3'
# [2015/Jul/07 13:15:16 INFO    ] > 113) target 'Urotensin II', genes 'UTS2R ' -> symbols 'UTS2R'
# [2015/Jul/07 13:15:17 INFO    ] > 114) target 'ERb', genes 'ESR2' -> symbols 'ESR2'
# [2015/Jul/07 13:15:17 INFO    ] > 115) target '5-HT transporter', genes 'SLC6A4' -> symbols 'SLC6A4'
# [2015/Jul/07 13:15:17 INFO    ] > 116) target '5-HT2B', genes 'HTR2B' -> symbols 'HTR2B'
# [2015/Jul/07 13:15:17 INFO    ] > 117) target '5-HT2C', genes 'HTR2C' -> symbols 'HTR2C'
# [2015/Jul/07 13:15:18 INFO    ] > 118) target '5-HT4e', genes 'HTR4' -> symbols 'HTR4'
# [2015/Jul/07 13:15:18 INFO    ] > 119) target '5-HT7', genes 'HTR7' -> symbols 'HTR7'
# [2015/Jul/07 13:15:18 INFO    ] > 120) target 'A2B', genes 'ADORA2B' -> symbols 'ADORA2B'
# [2015/Jul/07 13:15:19 INFO    ] > 121) target 'ACE', genes 'ACE' -> symbols 'ACE'
# [2015/Jul/07 13:15:19 INFO    ] > 122) target 'acetylcholinesterase', genes 'ACHE' -> symbols 'ACHE'
# [2015/Jul/07 13:15:19 INFO    ] > 123) target 'adenylyl cyclase', genes 'ADCY5' -> symbols 'ADCY5'
# [2015/Jul/07 13:15:20 INFO    ] > 124) target 'alpha1A', genes 'ADRA1A' -> symbols 'ADRA1A'
# [2015/Jul/07 13:15:20 INFO    ] > 125) target 'alpha2B', genes 'ADRA2B' -> symbols 'ADRA2B'
# [2015/Jul/07 13:15:20 INFO    ] > 126) target 'AR', genes 'AR' -> symbols 'AR'
# [2015/Jul/07 13:15:20 INFO    ] > 127) target 'AT1', genes 'AGTR1' -> symbols 'AGTR1'
# [2015/Jul/07 13:15:20 INFO    ] > 128) target 'ATPase (Na+/K+)', genes 'ATP1A1-4 & ATP1B1-4' -> symbols 'ATP1A1', 'ATP1A2', 'ATP1A3', 'ATP1A4', 'ATP1B1', 'ATP1B2', 'ATP1B3', 'ATP1B4'
# [2015/Jul/07 13:15:24 INFO    ] > 129) target 'beta1', genes 'ADRB1' -> symbols 'ADRB1'
# [2015/Jul/07 13:15:24 INFO    ] > 130) target 'Ca2+ L (diltiazem site)', genes 'CACNA1C' -> symbols 'CACNA1C'
# [2015/Jul/07 13:15:24 INFO    ] > 131) target 'COX2', genes 'PTGS2' -> symbols 'PTGS2'
# [2015/Jul/07 13:15:24 INFO    ] > 132) target 'D1', genes 'DRD1' -> symbols 'DRD1'
# [2015/Jul/07 13:15:24 INFO    ] > 133) target 'D4.4', genes 'DRD4' -> symbols 'DRD4'
# [2015/Jul/07 13:15:25 INFO    ] > 134) target 'delta2 (DOP)', genes 'OPRD1' -> symbols 'OPRD1'
# [2015/Jul/07 13:15:25 INFO    ] > 135) target 'GSK3a', genes 'GSK3A' -> symbols 'GSK3A'
# [2015/Jul/07 13:15:25 INFO    ] > 136) target 'H2', genes 'HRH2' -> symbols 'HRH2'
# [2015/Jul/07 13:15:25 INFO    ] > 137) target 'hERG ', genes 'KCNH2' -> symbols 'KCNH2'
# [2015/Jul/07 13:15:25 INFO    ] > 138) target 'kappa (KOP)', genes 'OPRK1' -> symbols 'OPRK1'
# [2015/Jul/07 13:15:25 INFO    ] > 139) target 'M2', genes 'CHRM2' -> symbols 'CHRM2'
# [2015/Jul/07 13:15:25 INFO    ] > 140) target 'MAO-A', genes 'MAOA' -> symbols 'MAOA'
# [2015/Jul/07 13:15:25 INFO    ] > 141) target 'MT3 (ML2)', genes 'MTNR1A, MTNR1B' -> symbols 'MTNR1A', 'MTNR1B'
# [2015/Jul/07 13:15:26 INFO    ] > 142) target 'Na+ site 2', genes 'SCN5A' -> symbols 'SCN5A'
# [2015/Jul/07 13:15:26 INFO    ] > 143) target 'NE transporter', genes 'SLC6A2' -> symbols 'SLC6A2'
# [2015/Jul/07 13:15:26 INFO    ] > 144) target 'PDE3A', genes 'PDE3A' -> symbols 'PDE3A'
# [2015/Jul/07 13:15:26 INFO    ] > 145) target 'tyrosine hydroxylase', genes 'TH' -> symbols 'TH'
# [2015/Jul/07 13:15:26 INFO    ] > 146) target 'UT', genes 'UTS2R' -> symbols 'UTS2R'
# [2015/Jul/07 13:15:26 INFO    ] > 147) target 'INa', genes 'SCN5A' -> symbols 'SCN5A'
# [2015/Jul/07 13:15:26 INFO    ] > 148) target 'ICa,L', genes 'CACNA1C' -> symbols 'CACNA1C'
# [2015/Jul/07 13:15:26 INFO    ] > 149) target 'ICa,T', genes 'CACNA1G,CACNA1H' -> symbols 'CACNA1G', 'CACNA1H'
# [2015/Jul/07 13:15:27 INFO    ] > 150) target 'Ito,f', genes 'KCND2,KCND3' -> symbols 'KCND2', 'KCND3'
# [2015/Jul/07 13:15:28 INFO    ] > 151) target 'Ito,s', genes 'KCNA4,KCNA7,KCNC4' -> symbols 'KCNA4', 'KCNA7', 'KCNC4'
# [2015/Jul/07 13:15:29 INFO    ] > 152) target 'IKur', genes 'KCNA5,KCNC1' -> symbols 'KCNA5', 'KCNC1'
# [2015/Jul/07 13:15:30 INFO    ] > 153) target 'IKr', genes 'KCNH2' -> symbols 'KCNH2'
# [2015/Jul/07 13:15:30 INFO    ] > 154) target 'IKs', genes 'KCNQ1' -> symbols 'KCNQ1'
# [2015/Jul/07 13:15:30 INFO    ] > 155) target 'IK1', genes 'KCNJ2,KCNJ12' -> symbols 'KCNJ2', 'KCNJ12'
# [2015/Jul/07 13:15:31 INFO    ] > 156) target 'IKATP', genes 'KCNJ11' -> symbols 'KCNJ11'
# [2015/Jul/07 13:15:31 INFO    ] > 157) target 'IKAch', genes 'KCNJ3/5' -> symbols 'KCNJ3', 'KCNJ5'
# [2015/Jul/07 13:15:32 INFO    ] > 158) target 'IKP', genes 'KCNK1,KCNK6,KCNK3,KCNK4' -> symbols 'KCNK1', 'KCNK6', 'KCNK3', 'KCNK4'
# [2015/Jul/07 13:15:34 INFO    ] > 159) target 'If', genes 'HCN2,HCN4' -> symbols 'HCN2', 'HCN4'
# [2015/Jul/07 13:15:35 INFO    ] > 160) target 'RAF1/BRAF', genes 'BRAF' -> symbols 'BRAF'
# [2015/Jul/07 13:15:36 INFO    ] > 161) target 'PI3K (p110α)', genes 'PIK3CA' -> symbols 'PIK3CA'
# [2015/Jul/07 13:15:36 INFO    ] > 162) target 'PI3K (p110γ)', genes 'PIK3CG' -> symbols 'PIK3CG'
# [2015/Jul/07 13:15:36 INFO    ] > 163) target 'PDK1', genes 'PDPK1' -> symbols 'PDPK1'
# [2015/Jul/07 13:15:37 INFO    ] > 164) target 'AKT1, 2 or 3', genes 'AKT1/2/3' -> symbols 'AKT1', 'AKT2', 'AKT3'
# [2015/Jul/07 13:15:38 INFO    ] > 165) target 'mTOR', genes 'MTOR' -> symbols 'MTOR'
# [2015/Jul/07 13:15:38 INFO    ] > 166) target 'AMPK', genes 'PRKAA1/2' -> symbols 'PRKAA1', 'PRKAA2'
# [2015/Jul/07 13:15:39 INFO    ] > 167) target 'GSK3α/β', genes 'GSK3A/B' -> symbols 'GSK3A', 'GSK3B'
# [2015/Jul/07 13:15:39 INFO    ] > 168) target 'CDKs', genes 'CDK2/4' -> symbols 'CDK2', 'CDK4'
# [2015/Jul/07 13:15:40 INFO    ] > 169) target 'Aurora kinases', genes 'AURKA/B/C' -> symbols 'AURKA', 'AURKB', 'AURKC'
# [2015/Jul/07 13:15:41 INFO    ] > 170) target 'PLKs', genes 'PLK1' -> symbols 'PLK1'
# [2015/Jul/07 13:15:42 INFO    ] > 171) target 'PDGFRs', genes 'PDGFRA/B' -> symbols 'PDGFRA', 'PDGFRB'
# [2015/Jul/07 13:15:43 INFO    ] > 172) target 'VEGFRs', genes 'FLT1, KDR, FLT4' -> symbols 'FLT1', 'KDR', 'FLT4'
# [2015/Jul/07 13:15:44 INFO    ] > 173) target 'EGFR (ERBB1)', genes 'EGFR' -> symbols 'EGFR'
# [2015/Jul/07 13:15:44 INFO    ] > 174) target 'ERBB2', genes 'ERBB2' -> symbols 'ERBB2'
# [2015/Jul/07 13:15:45 INFO    ] > 175) target 'KIT', genes 'KIT' -> symbols 'KIT'
# [2015/Jul/07 13:15:45 INFO    ] > 176) target 'ABL/ARG', genes 'ABL1' -> symbols 'ABL1'
# [2015/Jul/07 13:15:45 INFO    ] > 177) target 'JAK2', genes 'JAK2' -> symbols 'JAK2'
# [2015/Jul/07 13:15:46 INFO    ] > 178) target 'FAK', genes 'PTK2' -> symbols 'PTK2'
# [2015/Jul/07 13:15:46 INFO    ] > 179) target 'DMPK', genes 'DMPK' -> symbols 'DMPK'
# [2015/Jul/07 13:15:47 INFO    ] > 180) target 'LTK', genes 'LTK' -> symbols 'LTK'
# [2015/Jul/07 13:15:47 INFO    ] > 181) target 'ROCK', genes 'ROCK1/2' -> symbols 'ROCK1', 'ROCK2'
# [2015/Jul/07 13:15:48 INFO    ] > 182) target 'LKB1', genes 'STK11' -> symbols 'STK11'
# [2015/Jul/07 13:15:49 INFO    ] > 183) target 'ERK1/2', genes 'MAPK3/1' -> symbols 'MAPK3', 'MAPK1'
# [2015/Jul/07 13:15:49 INFO    ] > 184) target 'PKCα', genes 'PRKCA' -> symbols 'PRKCA'
# [2015/Jul/07 13:15:50 INFO    ] > 185) target 'PKG', genes 'PRKG1' -> symbols 'PRKG1'
# [2015/Jul/07 13:15:50 INFO    ] > 186) target 'PIM Kinase', genes 'PIM1' -> symbols 'PIM1'
# [2015/Jul/07 13:15:51 INFO    ] > 187) target 'CAMKII', genes 'CAMK2A' -> symbols 'CAMK2A'
# [2015/Jul/07 13:15:51 INFO    ] > 188) target 'GRK2, GRK5', genes 'ADRBK1, GRK5' -> symbols 'ADRBK1', 'GRK5'
# [2015/Jul/07 13:15:52 INFO    ] > 189) target 'ASK1', genes 'MAP3K5' -> symbols 'MAP3K5'
# [2015/Jul/07 13:15:52 INFO    ] > 190) target 'NTCP', genes 'SLC10A1' -> symbols 'SLC10A1'
# [2015/Jul/07 13:15:53 INFO    ] > 191) target 'BSEP', genes 'ABCB11' -> symbols 'ABCB11'
# [2015/Jul/07 13:15:53 INFO    ] > 192) target 'ASBT', genes 'SLC10A2' -> symbols 'SLC10A2'
# [2015/Jul/07 13:15:54 INFO    ] > 193) target 'OSTα/OSTβ', genes 'SLC51A/B' -> symbols 'SLC51A', 'SLC51B'
# [2015/Jul/07 13:15:55 INFO    ] > 194) target 'NTCP', genes 'SLC10A1' -> symbols 'SLC10A1'
# [2015/Jul/07 13:15:55 INFO    ] > 195) target 'OATPs', genes 'SLCO1A2/1B1/1B3/2B1' -> symbols 'SLCO1A2', 'SLCO1B1', 'SLCO1B3', 'SLCO2B1'
# [2015/Jul/07 13:15:57 INFO    ] > 196) target 'OCTs', genes 'SLC22A1' -> symbols 'SLC22A1'
# [2015/Jul/07 13:15:57 INFO    ] > 197) target 'OATs', genes 'SLC22A7/9' -> symbols 'SLC22A7', 'SLC22A9'
# [2015/Jul/07 13:15:58 INFO    ] > 198) target 'MRP3', genes 'ABCC3' -> symbols 'ABCC3'
# [2015/Jul/07 13:15:59 INFO    ] > 199) target 'MRP4', genes 'ABCC4' -> symbols 'ABCC4'
# [2015/Jul/07 13:15:59 INFO    ] > 200) target 'MDR1', genes 'ABCB1' -> symbols 'ABCB1'
# [2015/Jul/07 13:15:59 INFO    ] > 201) target 'MDR3', genes 'ABCB4' -> symbols 'ABCB4'
# [2015/Jul/07 13:16:00 INFO    ] > 202) target 'MRP2', genes 'ABCC2' -> symbols 'ABCC2'
# [2015/Jul/07 13:16:00 INFO    ] > 203) target 'BSEP', genes 'ABCB11' -> symbols 'ABCB11'
# [2015/Jul/07 13:16:00 INFO    ] > 204) target 'ABCG5', genes 'ABCG5' -> symbols 'ABCG5'
# [2015/Jul/07 13:16:01 INFO    ] > 205) target 'ABCG8', genes 'ABCG8' -> symbols 'ABCG8'
# [2015/Jul/07 13:16:01 INFO    ] > 206) target 'BCRP', genes 'ABCG2' -> symbols 'ABCG2'
# [2015/Jul/07 13:16:02 INFO    ] > 207) target 'AE2', genes 'SLC4A2' -> symbols 'SLC4A2'
# [2015/Jul/07 13:16:02 INFO    ] > 208) target 'ASBT', genes 'SLC10A2' -> symbols 'SLC10A2'
# [2015/Jul/07 13:16:02 INFO    ] > 209) target 'FIC1', genes 'ATP8B1' -> symbols 'ATP8B1'
# [2015/Jul/07 13:16:03 INFO    ] > 210) target 'OATP1B1', genes 'SLCO1B1' -> symbols 'SLCO1B1'
# [2015/Jul/07 13:16:03 INFO    ] > 211) target 'OATP1B3', genes 'SLCO1B3' -> symbols 'SLCO1B3'
# [2015/Jul/07 13:16:03 INFO    ] > 212) target 'OATP1A2', genes 'SLCO1A2' -> symbols 'SLCO1A2'
# [2015/Jul/07 13:16:03 INFO    ] > 213) target 'OATP2B1', genes 'SLCO2B1' -> symbols 'SLCO2B1'
# [2015/Jul/07 13:16:03 INFO    ] > 214) target 'OCT1', genes 'SLC22A1' -> symbols 'SLC22A1'
# [2015/Jul/07 13:16:03 INFO    ] > 215) target 'MATE1', genes 'SLC47A1' -> symbols 'SLC47A1'
# [2015/Jul/07 13:16:03 INFO    ] > 216) target 'MATE2-K', genes 'SLC47A2' -> symbols 'SLC47A2'
# [2015/Jul/07 13:16:03 INFO    ] > 217) target 'MDR1', genes 'ABCB1' -> symbols 'ABCB1'
# [2015/Jul/07 13:16:03 INFO    ] > 218) target 'BCRP', genes 'ABCG2' -> symbols 'ABCG2'
# [2015/Jul/07 13:16:03 INFO    ] > 219) target 'BSEP', genes 'ABCB11' -> symbols 'ABCB11'
# [2015/Jul/07 13:16:03 INFO    ] > 220) target 'MRP2', genes 'ABCC2' -> symbols 'ABCC2'
# [2015/Jul/07 13:16:03 INFO    ] > 221) target 'MRP3', genes 'ABCC3' -> symbols 'ABCC3'
# [2015/Jul/07 13:16:03 INFO    ] > 222) target 'MRP4', genes 'ABCC4' -> symbols 'ABCC4'
# [2015/Jul/07 13:16:03 INFO    ] > 223) target 'MDR3', genes 'ABCB4' -> symbols 'ABCB4'
# [2015/Jul/07 13:16:03 INFO    ] > 224) target 'OAT2', genes 'SLC22A7' -> symbols 'SLC22A7'
# [2015/Jul/07 13:16:03 INFO    ] > 225) target 'OAT7', genes 'SLC22A9' -> symbols 'SLC22A9'
# [2015/Jul/07 13:16:03 INFO    ] > 226) target 'NTCP', genes 'SLC10A1' -> symbols 'SLC10A1'
# [2015/Jul/07 13:16:03 INFO    ] > 227) target 'OSTα/β', genes 'SLC51A/B' -> symbols 'SLC51A', 'SLC51B'
# [2015/Jul/07 13:16:03 INFO    ] > 228) target 'MRP6', genes 'ABCC6' -> symbols 'ABCC6'
# [2015/Jul/07 13:16:04 INFO    ] > 229) target 'ENT1/2', genes 'SLC29A1/2' -> symbols 'SLC29A1', 'SLC29A2'
# [2015/Jul/07 13:16:04 INFO    ] > 230) target 'FXR', genes 'NR1H4' -> symbols 'NR1H4'
# [2015/Jul/07 13:16:05 INFO    ] > 231) target 'SHP', genes 'NR0B2' -> symbols 'NR0B2'
# [2015/Jul/07 13:16:05 INFO    ] > 232) target 'PXR', genes 'NR1I2' -> symbols 'NR1I2'
# [2015/Jul/07 13:16:06 INFO    ] > 233) target 'CAR', genes 'NR1I3' -> symbols 'NR1I3'
# [2015/Jul/07 13:16:06 INFO    ] > 234) target 'VDR', genes 'VDR' -> symbols 'VDR'
# [2015/Jul/07 13:16:06 INFO    ] > 235) target 'HNF4α', genes 'HNF4A' -> symbols 'HNF4A'
# [2015/Jul/07 13:16:07 INFO    ] > 236) target 'LRH1', genes 'NR5A2' -> symbols 'NR5A2'
# [2015/Jul/07 13:16:07 INFO    ] > 237) target 'PPARα', genes 'PPARA' -> symbols 'PPARA'
# [2015/Jul/07 13:16:08 INFO    ] > 238) target 'PPARγ', genes 'PPARG' -> symbols 'PPARG'
# [2015/Jul/07 13:16:08 INFO    ] > 239) target 'LXRα', genes 'NR1H3' -> symbols 'NR1H3'
# [2015/Jul/07 13:16:09 INFO    ] > 240) target 'LXRβ', genes 'NR1H2' -> symbols 'NR1H2'
# [2015/Jul/07 13:16:09 INFO    ] > 241) target 'GR', genes 'NR3C1' -> symbols 'NR3C1'
# [2015/Jul/07 13:16:10 INFO    ] > 242) target 'AhR', genes 'AHR' -> symbols 'AHR'
# [2015/Jul/07 13:16:10 INFO    ] > 243) target 'Nrf2', genes 'NFE2L2' -> symbols 'NFE2L2'
# [2015/Jul/07 13:16:11 INFO    ] > 244) target 'ACE', genes 'ACE' -> symbols 'ACE'
# [2015/Jul/07 13:16:11 INFO    ] > 245) target 'alpha2A', genes 'ADRA2A' -> symbols 'ADRA2A'
# [2015/Jul/07 13:16:11 INFO    ] > 246) target 'AR', genes 'AR' -> symbols 'AR'
# [2015/Jul/07 13:16:11 INFO    ] > 247) target 'ATPase (Na+/K+)', genes 'ATP1A1-4 & ATP1B1-4' -> symbols 'ATP1A1', 'ATP1A2', 'ATP1A3', 'ATP1A4', 'ATP1B1', 'ATP1B2', 'ATP1B3', 'ATP1B4'
# [2015/Jul/07 13:16:11 INFO    ] > 248) target 'beta2', genes 'ADRB2' -> symbols 'ADRB2'
# [2015/Jul/07 13:16:11 INFO    ] > 249) target 'carbonic anhydrase II', genes 'CA2' -> symbols 'CA2'
# [2015/Jul/07 13:16:11 INFO    ] > 250) target 'constitutive NOS (endothelial)', genes 'NOS3' -> symbols 'NOS3'
# [2015/Jul/07 13:16:11 INFO    ] > 251) target 'COX2', genes 'PTGS2' -> symbols 'PTGS2'
# [2015/Jul/07 13:16:11 INFO    ] > 252) target 'D4.4', genes 'DRD4' -> symbols 'DRD4'
# [2015/Jul/07 13:16:11 INFO    ] > 253) target 'ERalpha', genes 'ESR1' -> symbols 'ESR1'
# [2015/Jul/07 13:16:12 INFO    ] > 254) target 'ERK2 (P42mapk)', genes 'MAPK1' -> symbols 'MAPK1'
# [2015/Jul/07 13:16:12 INFO    ] > 255) target 'ETB', genes 'EDNRB' -> symbols 'EDNRB'
# [2015/Jul/07 13:16:12 INFO    ] > 256) target 'GR', genes 'NR3C1' -> symbols 'NR3C1'
# [2015/Jul/07 13:16:12 INFO    ] > 257) target 'GSK3a', genes 'GSK3A' -> symbols 'GSK3A'
# [2015/Jul/07 13:16:12 INFO    ] > 258) target 'H2', genes 'HRH2' -> symbols 'HRH2'
# [2015/Jul/07 13:16:12 INFO    ] > 259) target 'MAO-A', genes 'MAOA' -> symbols 'MAOA'
# [2015/Jul/07 13:16:12 INFO    ] > 260) target 'motilin', genes 'MLNR' -> symbols 'MLNR'
# [2015/Jul/07 13:16:12 INFO    ] > 261) target 'Na+ site 2', genes 'SCN5A' -> symbols 'SCN5A'
# [2015/Jul/07 13:16:12 INFO    ] > 262) target 'NMDA', genes 'GRIN1' -> symbols 'GRIN1'
# [2015/Jul/07 13:16:13 INFO    ] > 263) target 'cytochrome P450, family 1, subfamily A, polypeptide 1', genes 'CYP1A1' -> symbols 'CYP1A1'
# [2015/Jul/07 13:16:13 INFO    ] > 264) target 'cytochrome P450, family 1, subfamily A, polypeptide 2', genes 'CYP1A2' -> symbols 'CYP1A2'
# [2015/Jul/07 13:16:13 INFO    ] > 265) target 'cytochrome P450, family 2, subfamily A, polypeptide 6', genes 'CYP2A6' -> symbols 'CYP2A6'
# [2015/Jul/07 13:16:14 INFO    ] > 266) target 'cytochrome P450, family 2, subfamily B, polypeptide 6', genes 'CYP2B6' -> symbols 'CYP2B6'
# [2015/Jul/07 13:16:14 INFO    ] > 267) target 'cytochrome P450, family 2, subfamily C, polypeptide 8', genes 'CYP2C8' -> symbols 'CYP2C8'
# [2015/Jul/07 13:16:15 INFO    ] > 268) target 'cytochrome P450, family 2, subfamily C, polypeptide 9', genes 'CYP2C9' -> symbols 'CYP2C9'
# [2015/Jul/07 13:16:15 INFO    ] > 269) target 'cytochrome P450, family 2, subfamily C, polypeptide 19', genes 'CYP2C19' -> symbols 'CYP2C19'
# [2015/Jul/07 13:16:16 INFO    ] > 270) target 'cytochrome P450, family 2, subfamily D, polypeptide 6', genes 'CYP2D6' -> symbols 'CYP2D6'
# [2015/Jul/07 13:16:16 INFO    ] > 271) target 'cytochrome P450, family 2, subfamily E, polypeptide 1', genes 'CYP2E1' -> symbols 'CYP2E1'
# [2015/Jul/07 13:16:17 INFO    ] > 272) target 'cytochrome P450, family 3, subfamily A, polypeptide 4', genes 'CYP3A4' -> symbols 'CYP3A4'
# [2015/Jul/07 13:16:17 INFO    ] > 273) target 'cytochrome P450, family 3, subfamily A, polypeptide 5', genes 'CYP3A5' -> symbols 'CYP3A5'
# [2015/Jul/07 13:16:17 INFO    ] > 274) target 'dihydropyrimidine dehydrogenase', genes 'DPYD' -> symbols 'DPYD'
# [2015/Jul/07 13:16:18 INFO    ] > 275) target 'glutathione S-transferase M1', genes 'GSTM1' -> symbols 'GSTM1'
# [2015/Jul/07 13:16:18 INFO    ] > 276) target 'glutathione S-transferase pi', genes 'GSTP1' -> symbols 'GSTP1'
# [2015/Jul/07 13:16:19 INFO    ] > 277) target 'glutathione S-transferase theta 1', genes 'GSTT1' -> symbols 'GSTT1'
# [2015/Jul/07 13:16:19 INFO    ] > 278) target 'N-acetyltransferase 1 (arylamine N-acetyltransferase)', genes 'NAT1' -> symbols 'NAT1'
# [2015/Jul/07 13:16:19 INFO    ] > 279) target 'N-acetyltransferase 2 (arylamine N-acetyltransferase)', genes 'NAT2' -> symbols 'NAT2'
# [2015/Jul/07 13:16:20 INFO    ] > 280) target 'sulfotransferase family, cytosolic, 1A, phenol-preferring, member 1', genes 'SULT1A1' -> symbols 'SULT1A1'
# [2015/Jul/07 13:16:20 INFO    ] > 281) target 'thiopurine S-methyltransferase', genes 'TPMT' -> symbols 'TPMT'
# [2015/Jul/07 13:16:21 INFO    ] > 282) target 'UDP glucuronosyltransferase 1 family, polypeptide A1', genes 'UGT1A1' -> symbols 'UGT1A1'
# [2015/Jul/07 13:16:21 INFO    ] > 283) target 'UDP glucuronosyltransferase 2 family, polypeptide B15', genes 'UGT2B15' -> symbols 'UGT2B15'
# [2015/Jul/07 13:16:22 INFO    ] > 284) target 'UDP glucuronosyltransferase 2 family, polypeptide B17', genes 'UGT2B17' -> symbols 'UGT2B17'
# [2015/Jul/07 13:16:22 INFO    ] > 285) target 'UDP glucuronosyltransferase 2 family, polypeptide B7', genes 'UGT2B7' -> symbols 'UGT2B7'
# [2015/Jul/07 13:16:22 INFO    ] > 286) target 'ATP-binding cassette, sub-family B (MDR/TAP), member 1', genes 'ABCB1' -> symbols 'ABCB1'
# [2015/Jul/07 13:16:22 INFO    ] > 287) target 'ATP-binding cassette, sub-family C (CFTR/MRP), member 2', genes 'ABCC2' -> symbols 'ABCC2'
# [2015/Jul/07 13:16:22 INFO    ] > 288) target 'ATP-binding cassette, sub-family G (WHITE), member 2', genes 'ABCG2' -> symbols 'ABCG2'
# [2015/Jul/07 13:16:22 INFO    ] > 289) target 'solute carrier family 15 (H+/peptide transporter), member 2', genes 'SLC15A2' -> symbols 'SLC15A2'
# [2015/Jul/07 13:16:23 INFO    ] > 290) target 'solute carrier family 22 (organic cation transporter), member 1', genes 'SLC22A1' -> symbols 'SLC22A1'
# [2015/Jul/07 13:16:23 INFO    ] > 291) target 'solute carrier family 22 (organic cation transporter), member 2', genes 'SLC22A2' -> symbols 'SLC22A2'
# [2015/Jul/07 13:16:23 INFO    ] > 292) target 'solute carrier family 22 (organic anion transporter), member 6', genes 'SLC22A6' -> symbols 'SLC22A6'
# [2015/Jul/07 13:16:24 INFO    ] > 293) target 'solute carrier organic anion transporter family, member 1B1', genes 'SLCO1B1' -> symbols 'SLCO1B1'
# [2015/Jul/07 13:16:24 INFO    ] > 294) target 'solute carrier organic anion transporter family, member 1B3', genes 'SLCO1B3' -> symbols 'SLCO1B3'
# [2015/Jul/07 13:16:24 INFO    ] Finished: did 294 input records in total.

# %%
df1.shape
# Out:
# (344, 6)

# %%
df1.head()
# Out:
#                     target    genes table  n_symbol   symbol                 approved_name
# 0   Adenosine receptor A2A  ADORA2A     1         1  ADORA2A        adenosine A2a receptor
# 1  α1A-adrenergic receptor   ADRA1A     1         1   ADRA1A         adrenoceptor alpha 1A
# 2  α2A-adrenergic receptor   ADRA2A     1         1   ADRA2A         adrenoceptor alpha 2A
# 3   β1-adrenergic receptor    ADRB1     1         1    ADRB1           adrenoceptor beta 1
# 4   β2-adrenergic receptor    ADRB2     1         1    ADRB2  adrenoceptor beta 2, surface

# %%
# Save/restore...

df1.to_pickle('raw_target_data.pkl')

# %%
# df1 = pd.read_pickle('raw_target_data.pkl')

# %% [markdown]
# ### Get list of unique Symbols

# %%
def f(group):
        
    targets = tuple(tuple(x) for x in group[['target', 'table']].values)
            
    return pd.Series({'targets': targets})

symbols = df1.groupby(['symbol', 'approved_name']).apply(f).reset_index().set_index('symbol', drop=False)

symbols.shape
# Out:
# (215, 3)

# %%
symbols
# Out:
#           symbol                                                                          approved_name                                                                                                                                                            targets
# symbol
# ABCB1      ABCB1                                 ATP-binding cassette, sub-family B (MDR/TAP), member 1                                                                               ((MDR1, 7), (MDR1, 8), (ATP-binding cassette, sub-family B (MDR/TAP), member 1, 11))
# ABCB11    ABCB11                                ATP-binding cassette, sub-family B (MDR/TAP), member 11                                                                                                                                  ((BSEP, 6), (BSEP, 7), (BSEP, 8))
# ABCB4      ABCB4                                 ATP-binding cassette, sub-family B (MDR/TAP), member 4                                                                                                                                             ((MDR3, 7), (MDR3, 8))
# ABCC2      ABCC2                                ATP-binding cassette, sub-family C (CFTR/MRP), member 2                                                                              ((MRP2, 7), (MRP2, 8), (ATP-binding cassette, sub-family C (CFTR/MRP), member 2, 11))
# ABCC3      ABCC3                                ATP-binding cassette, sub-family C (CFTR/MRP), member 3                                                                                                                                             ((MRP3, 7), (MRP3, 8))
# ABCC4      ABCC4                                ATP-binding cassette, sub-family C (CFTR/MRP), member 4                                                                                                                                             ((MRP4, 7), (MRP4, 8))
# ABCC6      ABCC6                                ATP-binding cassette, sub-family C (CFTR/MRP), member 6                                                                                                                                                       ((MRP6, 8),)
# ABCG2      ABCG2              ATP-binding cassette, sub-family G (WHITE), member 2 (Junior blood group)                                                                                 ((BCRP, 7), (BCRP, 8), (ATP-binding cassette, sub-family G (WHITE), member 2, 11))
# ABCG5      ABCG5                                   ATP-binding cassette, sub-family G (WHITE), member 5                                                                                                                                                      ((ABCG5, 7),)
# ABCG8      ABCG8                                   ATP-binding cassette, sub-family G (WHITE), member 8                                                                                                                                                      ((ABCG8, 7),)
# ABL1        ABL1                                     ABL proto-oncogene 1, non-receptor tyrosine kinase                                                                                                                                                    ((ABL/ARG, 5),)
# ACE          ACE                                                        angiotensin I converting enzyme                                                                                                                                              ((ACE, 3), (ACE, 10))
# ACHE        ACHE                                                  acetylcholinesterase (Yt blood group)                                                                                                             ((Acetylcholinesterase, 1), (acetylcholinesterase, 3))
# ADCY5      ADCY5                                                                    adenylate cyclase 5                                                                                                                                           ((adenylyl cyclase, 3),)
# ADORA1    ADORA1                                                                  adenosine A1 receptor                                                                                                           ((Adenosine A1, 2.1), (Adenosine 1 receptor (Ad1), 2.2))
# ADORA2A  ADORA2A                                                                 adenosine A2a receptor                                                                           ((Adenosine receptor A2A, 1), (Adenosine A2A, 2.1), (Adenosine 2a receptor (Ad2a), 2.2))
# ADORA2B  ADORA2B                                                                 adenosine A2b receptor                                                                                                                                                        ((A2B, 3),)
# ADORA3    ADORA3                                                                  adenosine A3 receptor                                                                                                                 ((Adenosine A3, 2.1), (Adenosine 3 receptor, 2.2))
# ADRA1A    ADRA1A                                                                  adrenoceptor alpha 1A                                                         ((α1A-adrenergic receptor, 1), (Adrenergic α1A, 2.1), (Adrenergic α1a receptor (Al1a), 2.2), (alpha1A, 3))
# ADRA1B    ADRA1B                                                                  adrenoceptor alpha 1B                                                                                                                                           ((Adrenergic α1B, 2.1),)
# ADRA1D    ADRA1D                                                                  adrenoceptor alpha 1D                                                                                                                                                  ((alpha1D, 2.2),)
# ADRA2A    ADRA2A                                                                  adrenoceptor alpha 2A                                                                        ((α2A-adrenergic receptor, 1), (Adrenergic α2A, 2.1), (Adrenergic α2A, 2.2), (alpha2A, 10))
# ADRA2B    ADRA2B                                                                  adrenoceptor alpha 2B                                                                                                                              ((Adrenergic α2B, 2.1), (alpha2B, 3))
# ADRA2C    ADRA2C                                                                  adrenoceptor alpha 2C                                                                                                     ((Adrenergic α2C, 2.1), (Adrenergic α2c receptor (Al2c), 2.2))
# ADRB1      ADRB1                                                                    adrenoceptor beta 1                                                                     ((β1-adrenergic receptor, 1), (Adrenergic β1, 2.1), (Adrenergic β1 receptor, 2.2), (beta1, 3))
# ADRB2      ADRB2                                                           adrenoceptor beta 2, surface                                                                    ((β2-adrenergic receptor, 1), (Adrenergic β2, 2.1), (Adrenergic β2 receptor, 2.2), (beta2, 10))
# ADRB3      ADRB3                                                                    adrenoceptor beta 3                                                                                                                                                    ((beta3, 2.2),)
# ADRBK1    ADRBK1                                                    adrenergic, beta, receptor kinase 1                                                                                                                                                 ((GRK2, GRK5, 5),)
# AGTR1      AGTR1                                                        angiotensin II receptor, type 1                                                                                          ((Angiotensin II AT1, 2.1), (Angiotensin II AT1 receptor, 2.2), (AT1, 3))
# AHR          AHR                                                              aryl hydrocarbon receptor                                                                                                                                                        ((AhR, 9),)
# AKT1        AKT1                                          v-akt murine thymoma viral oncogene homolog 1                                                                                                                            ((PKBa (AKT1), 2.2), (AKT1, 2 or 3, 5))
# AKT2        AKT2                                          v-akt murine thymoma viral oncogene homolog 2                                                                                                                                               ((AKT1, 2 or 3, 5),)
# AKT3        AKT3                                          v-akt murine thymoma viral oncogene homolog 3                                                                                                                                               ((AKT1, 2 or 3, 5),)
# APLNR      APLNR                                                                        apelin receptor                                                                                                                                                      ((APJ, 2.2),)
# AR            AR                                                                      androgen receptor                                                                                                                                                ((AR, 3), (AR, 10))
# ATP1A1    ATP1A1                                       ATPase, Na+/K+ transporting, alpha 1 polypeptide                                                                                                                      ((ATPase (Na+/K+), 3), (ATPase (Na+/K+), 10))
# ATP1A2    ATP1A2                                       ATPase, Na+/K+ transporting, alpha 2 polypeptide                                                                                                                      ((ATPase (Na+/K+), 3), (ATPase (Na+/K+), 10))
# ATP1A3    ATP1A3                                       ATPase, Na+/K+ transporting, alpha 3 polypeptide                                                                                                                      ((ATPase (Na+/K+), 3), (ATPase (Na+/K+), 10))
# ATP1A4    ATP1A4                                       ATPase, Na+/K+ transporting, alpha 4 polypeptide                                                                                                                      ((ATPase (Na+/K+), 3), (ATPase (Na+/K+), 10))
# ATP1B1    ATP1B1                                        ATPase, Na+/K+ transporting, beta 1 polypeptide                                                                                                                      ((ATPase (Na+/K+), 3), (ATPase (Na+/K+), 10))
# ATP1B2    ATP1B2                                        ATPase, Na+/K+ transporting, beta 2 polypeptide                                                                                                                      ((ATPase (Na+/K+), 3), (ATPase (Na+/K+), 10))
# ATP1B3    ATP1B3                                        ATPase, Na+/K+ transporting, beta 3 polypeptide                                                                                                                      ((ATPase (Na+/K+), 3), (ATPase (Na+/K+), 10))
# ATP1B4    ATP1B4                                        ATPase, Na+/K+ transporting, beta 4 polypeptide                                                                                                                      ((ATPase (Na+/K+), 3), (ATPase (Na+/K+), 10))
# ATP8B1    ATP8B1                      ATPase, aminophospholipid transporter, class I, type 8B, member 1                                                                                                                                                       ((FIC1, 7),)
# AURKA      AURKA                                                                        aurora kinase A                                                                                                                                             ((Aurora kinases, 5),)
# AURKB      AURKB                                                                        aurora kinase B                                                                                                                                             ((Aurora kinases, 5),)
# AURKC      AURKC                                                                        aurora kinase C                                                                                                                                             ((Aurora kinases, 5),)
# AVPR1A    AVPR1A                                                       arginine vasopressin receptor 1A                                                                                    ((Vasopressin V1A receptor, 1), (Vasopressin V1A, 2.1), (Vasopressin V1a, 2.2))
# AVPR1B    AVPR1B                                                       arginine vasopressin receptor 1B                                                                                                                                          ((Vasopressin V1B, 2.1),)
# BDKRB1    BDKRB1                                                                 bradykinin receptor B1                                                                                                                                            ((Bradykinin B1, 2.1),)
# BDKRB2    BDKRB2                                                                 bradykinin receptor B2                                                                                                                       ((Bradykinin B2, 2.1), (Bradykinin B2, 2.2))
# BRAF        BRAF                                          B-Raf proto-oncogene, serine/threonine kinase                                                                                                                                                  ((RAF1/BRAF, 5),)
# CA2          CA2                                                                  carbonic anhydrase II                                                                                                                                     ((carbonic anhydrase II, 10),)
# CACNA1C  CACNA1C                           calcium channel, voltage-dependent, L type, alpha 1C subunit  ((Voltage-gated calcium channel subunit α Cav1.2, 1), (Ca channel type L, 2.1), (Calcium channel (L type) Cav1.2, 2.2), (Ca2+ L (diltiazem site), 3), (ICa,L, 4))
# CACNA1G  CACNA1G                           calcium channel, voltage-dependent, T type, alpha 1G subunit                                                                                                                                                      ((ICa,T, 4),)
# CACNA1H  CACNA1H                           calcium channel, voltage-dependent, T type, alpha 1H subunit                                                                                                                                                      ((ICa,T, 4),)
# CALCR      CALCR                                                                    calcitonin receptor                                                                                                                                                    ((CGRP1, 2.2),)
# CALCRL    CALCRL                                                               calcitonin receptor-like                                                                                                                                                     ((CGRP, 2.1),)
# CAMK2A    CAMK2A                                   calcium/calmodulin-dependent protein kinase II alpha                                                                                                                                                     ((CAMKII, 5),)
# CDK2        CDK2                                                              cyclin-dependent kinase 2                                                                                                                                          ((CDK2A, 2.2), (CDKs, 5))
# CDK4        CDK4                                                              cyclin-dependent kinase 4                                                                                                                                                       ((CDKs, 5),)
# CHRM1      CHRM1                                                     cholinergic receptor, muscarinic 1                                                                            ((Muscarinic acetylcholine receptor M1, 1), (Muscarinic M1, 2.1), (Muscarinic M1, 2.2))
# CHRM2      CHRM2                                                     cholinergic receptor, muscarinic 2                                                                   ((Muscarinic acetylcholine receptor M2, 1), (Muscarinic M2, 2.1), (Muscarinic M2, 2.2), (M2, 3))
# CHRM3      CHRM3                                                     cholinergic receptor, muscarinic 3                                                                                                                                            ((Muscarinic M3, 2.1),)
# CHRM4      CHRM4                                                     cholinergic receptor, muscarinic 4                                                                                                                                            ((Muscarinic M4, 2.1),)
# CHRNA1    CHRNA1                                      cholinergic receptor, nicotinic, alpha 1 (muscle)                                                ((Acetylcholine receptor subunit α1 or α4, 1), (Nicotinic acetylcholine, 2.1), (Nicotinic receptor (central), 2.2))
# CHRNA4    CHRNA4                                    cholinergic receptor, nicotinic, alpha 4 (neuronal)                                                                                                                    ((Acetylcholine receptor subunit α1 or α4, 1),)
# CYP1A1    CYP1A1                                  cytochrome P450, family 1, subfamily A, polypeptide 1                                                                                                     ((cytochrome P450, family 1, subfamily A, polypeptide 1, 11),)
# CYP1A2    CYP1A2                                  cytochrome P450, family 1, subfamily A, polypeptide 2                                                                                                     ((cytochrome P450, family 1, subfamily A, polypeptide 2, 11),)
# CYP2A6    CYP2A6                                  cytochrome P450, family 2, subfamily A, polypeptide 6                                                                                                     ((cytochrome P450, family 2, subfamily A, polypeptide 6, 11),)
# CYP2B6    CYP2B6                                  cytochrome P450, family 2, subfamily B, polypeptide 6                                                                                                     ((cytochrome P450, family 2, subfamily B, polypeptide 6, 11),)
# CYP2C19  CYP2C19                                 cytochrome P450, family 2, subfamily C, polypeptide 19                                                                                                    ((cytochrome P450, family 2, subfamily C, polypeptide 19, 11),)
# CYP2C8    CYP2C8                                  cytochrome P450, family 2, subfamily C, polypeptide 8                                                                                                     ((cytochrome P450, family 2, subfamily C, polypeptide 8, 11),)
# CYP2C9    CYP2C9                                  cytochrome P450, family 2, subfamily C, polypeptide 9                                                                                                     ((cytochrome P450, family 2, subfamily C, polypeptide 9, 11),)
# CYP2D6    CYP2D6                                  cytochrome P450, family 2, subfamily D, polypeptide 6                                                                                                     ((cytochrome P450, family 2, subfamily D, polypeptide 6, 11),)
# CYP2E1    CYP2E1                                  cytochrome P450, family 2, subfamily E, polypeptide 1                                                                                                     ((cytochrome P450, family 2, subfamily E, polypeptide 1, 11),)
# CYP3A4    CYP3A4                                  cytochrome P450, family 3, subfamily A, polypeptide 4                                                                                                     ((cytochrome P450, family 3, subfamily A, polypeptide 4, 11),)
# CYP3A5    CYP3A5                                  cytochrome P450, family 3, subfamily A, polypeptide 5                                                                                                     ((cytochrome P450, family 3, subfamily A, polypeptide 5, 11),)
# DMPK        DMPK                                                    dystrophia myotonica-protein kinase                                                                                                                                                       ((DMPK, 5),)
# DPYD        DPYD                                                        dihydropyrimidine dehydrogenase                                                                                                                           ((dihydropyrimidine dehydrogenase, 11),)
# DRD1        DRD1                                                                   dopamine receptor D1                                                                                                           ((Dopamine receptor D1, 1), (Dopamine D1, 2.1), (D1, 3))
# DRD2        DRD2                                                                   dopamine receptor D2                                                                                                                                       ((Dopamine receptor D2, 1),)
# DRD4        DRD4                                                                   dopamine receptor D4                                                                                                                                            ((D4.4, 3), (D4.4, 10))
# EDNRA      EDNRA                                                             endothelin receptor type A                                                                                                   ((Endothelin receptor A, 1), (Endothelin ETa , 2.1), (ETa, 2.2))
# EDNRB      EDNRB                                                             endothelin receptor type B                                                                                                                     ((Endothelin ETb, 2.1), (ETb, 2.2), (ETB, 10))
# EGFR        EGFR                                                       epidermal growth factor receptor                                                                                                                                               ((EGFR (ERBB1), 5),)
# ERBB2      ERBB2                                                      erb-b2 receptor tyrosine kinase 2                                                                                                                                                      ((ERBB2, 5),)
# ESR1        ESR1                                                                    estrogen receptor 1                                                                                                                                                   ((ERalpha, 10),)
# ESR2        ESR2                                                          estrogen receptor 2 (ER beta)                                                                                                                                                      ((ERb, 2.2),)
# F2            F2                                                       coagulation factor II (thrombin)                                                                                                                                 ((Thrombin, 2.1), (Thrombin, 2.2))
# FLT1        FLT1                                                          fms-related tyrosine kinase 1                                                                                                                                                     ((VEGFRs, 5),)
# FLT4        FLT4                                                          fms-related tyrosine kinase 4                                                                                                                                                     ((VEGFRs, 5),)
# GCGR        GCGR                                                                      glucagon receptor                                                                                                                                                 ((Glucagon, 2.2),)
# GHSR        GHSR                                                   growth hormone secretagogue receptor                                                                                                                              ((Ghrelin GHSR, 2.1), (Ghrelin, 2.2))
# GRIN1      GRIN1                                 glutamate receptor, ionotropic, N-methyl D-aspartate 1                                                                                                                                                      ((NMDA, 10),)
# GRK5        GRK5                                                    G protein-coupled receptor kinase 5                                                                                                                                                 ((GRK2, GRK5, 5),)
# GSK3A      GSK3A                                                       glycogen synthase kinase 3 alpha                                                                                                                            ((GSK3a, 3), (GSK3α/β, 5), (GSK3a, 10))
# GSK3B      GSK3B                                                        glycogen synthase kinase 3 beta                                                                                                                                                    ((GSK3α/β, 5),)
# GSTM1      GSTM1                                                         glutathione S-transferase mu 1                                                                                                                              ((glutathione S-transferase M1, 11),)
# GSTP1      GSTP1                                                         glutathione S-transferase pi 1                                                                                                                              ((glutathione S-transferase pi, 11),)
# GSTT1      GSTT1                                                      glutathione S-transferase theta 1                                                                                                                         ((glutathione S-transferase theta 1, 11),)
# HCN2        HCN2                hyperpolarization activated cyclic nucleotide gated potassium channel 2                                                                                                                                                         ((If, 4),)
# HCN4        HCN4                hyperpolarization activated cyclic nucleotide gated potassium channel 4                                                                                                                                                         ((If, 4),)
# HNF4A      HNF4A                                                     hepatocyte nuclear factor 4, alpha                                                                                                                                                      ((HNF4α, 9),)
# HRH1        HRH1                                                                  histamine receptor H1                                                                                                                                      ((Histamine H1 receptor, 1),)
# HRH2        HRH2                                                                  histamine receptor H2                                                                                               ((Histamine H2 receptor, 1), (Histamine H2, 2.2), (H2, 3), (H2, 10))
# HRH3        HRH3                                                                  histamine receptor H3                                                                                                                                             ((Histamine H3, 2.1),)
# HTR1B      HTR1B                         5-hydroxytryptamine (serotonin) receptor 1B, G protein-coupled                                                                                                                                                     ((5-HT1B, 1),)
# HTR2A      HTR2A                         5-hydroxytryptamine (serotonin) receptor 2A, G protein-coupled                                                                                                                                                     ((5-HT2A, 1),)
# HTR2B      HTR2B                         5-hydroxytryptamine (serotonin) receptor 2B, G protein-coupled                                                                                                            ((5-HT2B, 1), (5-HT2B, 2.1), (5HT2b, 2.2), (5-HT2B, 3))
# HTR2C      HTR2C                         5-hydroxytryptamine (serotonin) receptor 2C, G protein-coupled                                                                                                                                                     ((5-HT2C, 3),)
# HTR4        HTR4                          5-hydroxytryptamine (serotonin) receptor 4, G protein-coupled                                                                                                                          ((5-HT4, 2.1), (5-HT4, 2.2), (5-HT4e, 3))
# HTR7        HTR7                  5-hydroxytryptamine (serotonin) receptor 7, adenylate cyclase-coupled                                                                                                                                                      ((5-HT7, 3),)
# JAK2        JAK2                                                                         Janus kinase 2                                                                                                                                                       ((JAK2, 5),)
# KCNA4      KCNA4                  potassium channel, voltage gated shaker related subfamily A, member 4                                                                                                                                                      ((Ito,s, 4),)
# KCNA5      KCNA5                  potassium channel, voltage gated shaker related subfamily A, member 5                                                                                                                                                       ((IKur, 4),)
# KCNA7      KCNA7                  potassium channel, voltage gated shaker related subfamily A, member 7                                                                                                                                                      ((Ito,s, 4),)
# KCNC1      KCNC1                    potassium channel, voltage gated Shaw related subfamily C, member 1                                                                                                                                                       ((IKur, 4),)
# KCNC4      KCNC4                    potassium channel, voltage gated Shaw related subfamily C, member 4                                                                                                                                                      ((Ito,s, 4),)
# KCND2      KCND2                    potassium channel, voltage gated Shal related subfamily D, member 2                                                                                                                                                      ((Ito,f, 4),)
# KCND3      KCND3                    potassium channel, voltage gated Shal related subfamily D, member 3                                                                                                                                                      ((Ito,f, 4),)
# KCNE1      KCNE1                 potassium channel, voltage gated subfamily E regulatory beta subunit 1                                                                       ((Potassium voltage-gated channel KQT-like member 1 and minimal potassium channel MinK, 1),)
# KCNH2      KCNH2                     potassium channel, voltage gated eag related subfamily H, member 2                                                 ((Potassium voltage-gated channel, subfamily H member 2 (hERG), 1), (K channel (hERG), 2.1), (hERG , 3), (IKr, 4))
# KCNJ11    KCNJ11                          potassium channel, inwardly rectifying subfamily J, member 11                                                                                                                ((K channel [ATP], 2.1), (K+ ATP, 2.2), (IKATP, 4))
# KCNJ12    KCNJ12                          potassium channel, inwardly rectifying subfamily J, member 12                                                                                                                                                        ((IK1, 4),)
# KCNJ2      KCNJ2                           potassium channel, inwardly rectifying subfamily J, member 2                                                                                                                                                        ((IK1, 4),)
# KCNJ3      KCNJ3                           potassium channel, inwardly rectifying subfamily J, member 3                                                                                                                                                      ((IKAch, 4),)
# KCNJ5      KCNJ5                           potassium channel, inwardly rectifying subfamily J, member 5                                                                                                                                                      ((IKAch, 4),)
# KCNK1      KCNK1                               potassium channel, two pore domain subfamily K, member 1                                                                                                                                                        ((IKP, 4),)
# KCNK3      KCNK3                               potassium channel, two pore domain subfamily K, member 3                                                                                                                                                        ((IKP, 4),)
# KCNK4      KCNK4                               potassium channel, two pore domain subfamily K, member 4                                                                                                                                                        ((IKP, 4),)
# KCNK6      KCNK6                               potassium channel, two pore domain subfamily K, member 6                                                                                                                                                        ((IKP, 4),)
# KCNQ1      KCNQ1                        potassium channel, voltage gated KQT-like subfamily Q, member 1                                                ((Potassium voltage-gated channel KQT-like member 1 and minimal potassium channel MinK, 1), (KCNQ1, 2.2), (IKs, 4))
# KDR          KDR                                                          kinase insert domain receptor                                                                                                                                                     ((VEGFRs, 5),)
# KIT          KIT                          v-kit Hardy-Zuckerman 4 feline sarcoma viral oncogene homolog                                                                                                                                                        ((KIT, 5),)
# LTK          LTK                                                     leukocyte receptor tyrosine kinase                                                                                                                                                        ((LTK, 5),)
# MAOA        MAOA                                                                    monoamine oxidase A                                                                                                  ((Monoamine oxidase A, 1), (MAO-A, 2.2), (MAO-A, 3), (MAO-A, 10))
# MAP3K5    MAP3K5                                       mitogen-activated protein kinase kinase kinase 5                                                                                                                                                       ((ASK1, 5),)
# MAPK1      MAPK1                                                     mitogen-activated protein kinase 1                                                                                                                                ((ERK1/2, 5), (ERK2 (P42mapk), 10))
# MAPK3      MAPK3                                                     mitogen-activated protein kinase 3                                                                                                                                                     ((ERK1/2, 5),)
# MLNR        MLNR                                                                       motilin receptor                                                                                                                                                   ((motilin, 10),)
# MTNR1A    MTNR1A                                                                  melatonin receptor 1A                                                                                                                                                  ((MT3 (ML2), 3),)
# MTNR1B    MTNR1B                                                                  melatonin receptor 1B                                                                                                                                                  ((MT3 (ML2), 3),)
# MTOR        MTOR                              mechanistic target of rapamycin (serine/threonine kinase)                                                                                                                                                       ((mTOR, 5),)
# NAT1        NAT1                                  N-acetyltransferase 1 (arylamine N-acetyltransferase)                                                                                                     ((N-acetyltransferase 1 (arylamine N-acetyltransferase), 11),)
# NAT2        NAT2                                  N-acetyltransferase 2 (arylamine N-acetyltransferase)                                                                                                     ((N-acetyltransferase 2 (arylamine N-acetyltransferase), 11),)
# NFE2L2    NFE2L2                                                     nuclear factor, erythroid 2-like 2                                                                                                                                                       ((Nrf2, 9),)
# NOS3        NOS3                                             nitric oxide synthase 3 (endothelial cell)                                                                                                                ((eNOS, 2.2), (constitutive NOS (endothelial), 10))
# NPR1        NPR1                                                         natriuretic peptide receptor 1                                                                                                                                                      ((ANF, 2.2),)
# NPR2        NPR2                                                         natriuretic peptide receptor 2                                                                                                                                                      ((ANF, 2.2),)
# NPY1R      NPY1R                                                             neuropeptide Y receptor Y1                                                                                                                            ((NPY Y1, 2.1), (Neuropeptide Y1, 2.2))
# NR0B2      NR0B2                                        nuclear receptor subfamily 0, group B, member 2                                                                                                                                                        ((SHP, 9),)
# NR1H2      NR1H2                                        nuclear receptor subfamily 1, group H, member 2                                                                                                                                                       ((LXRβ, 9),)
# NR1H3      NR1H3                                        nuclear receptor subfamily 1, group H, member 3                                                                                                                                                       ((LXRα, 9),)
# NR1H4      NR1H4                                        nuclear receptor subfamily 1, group H, member 4                                                                                                                                                        ((FXR, 9),)
# NR1I2      NR1I2                                        nuclear receptor subfamily 1, group I, member 2                                                                                                                                                        ((PXR, 9),)
# NR1I3      NR1I3                                        nuclear receptor subfamily 1, group I, member 3                                                                                                                                                        ((CAR, 9),)
# NR3C1      NR3C1              nuclear receptor subfamily 3, group C, member 1 (glucocorticoid receptor)                                                                                                                                                ((GR, 9), (GR, 10))
# NR5A2      NR5A2                                        nuclear receptor subfamily 5, group A, member 2                                                                                                                                                       ((LRH1, 9),)
# OPRD1      OPRD1                                                               opioid receptor, delta 1                                                                                                  ((δ-type opioid receptor, 1), (Opioid d, 2.2), (delta2 (DOP), 3))
# OPRK1      OPRK1                                                               opioid receptor, kappa 1                                                                                                   ((κ-type opioid receptor, 1), (Opioid k, 2.2), (kappa (KOP), 3))
# OPRM1      OPRM1                                                                  opioid receptor, mu 1                                                                                                                                     ((μ-type opioid receptor, 1),)
# PDE3A      PDE3A                                                   phosphodiesterase 3A, cGMP-inhibited                                                                                         ((Phosphodiesterase 3A, 1), (Phosphodiesterase 3 (PDE3), 2.2), (PDE3A, 3))
# PDE3B      PDE3B                                                   phosphodiesterase 3B, cGMP-inhibited                                                                                                                               ((Phosphodiesterase 3 (PDE3), 2.2),)
# PDGFRA    PDGFRA                             platelet-derived growth factor receptor, alpha polypeptide                                                                                                                                                     ((PDGFRs, 5),)
# PDGFRB    PDGFRB                              platelet-derived growth factor receptor, beta polypeptide                                                                                                                                                     ((PDGFRs, 5),)
# PDPK1      PDPK1                                          3-phosphoinositide dependent protein kinase 1                                                                                                                                                       ((PDK1, 5),)
# PIK3CA    PIK3CA                phosphatidylinositol-4,5-bisphosphate 3-kinase, catalytic subunit alpha                                                                                                                                               ((PI3K (p110α), 5),)
# PIK3CG    PIK3CG                phosphatidylinositol-4,5-bisphosphate 3-kinase, catalytic subunit gamma                                                                                                                                               ((PI3K (p110γ), 5),)
# PIM1        PIM1                                          Pim-1 proto-oncogene, serine/threonine kinase                                                                                                                                                 ((PIM Kinase, 5),)
# PLK1        PLK1                                                                     polo-like kinase 1                                                                                                                                                       ((PLKs, 5),)
# PPARA      PPARA                                       peroxisome proliferator-activated receptor alpha                                                                                                                                                      ((PPARα, 9),)
# PPARG      PPARG                                       peroxisome proliferator-activated receptor gamma                                                                                                                                                      ((PPARγ, 9),)
# PRKAA1    PRKAA1                               protein kinase, AMP-activated, alpha 1 catalytic subunit                                                                                                                                                       ((AMPK, 5),)
# PRKAA2    PRKAA2                               protein kinase, AMP-activated, alpha 2 catalytic subunit                                                                                                                                                       ((AMPK, 5),)
# PRKCA      PRKCA                                                                protein kinase C, alpha                                                                                                                                                       ((PKCα, 5),)
# PRKG1      PRKG1                                                 protein kinase, cGMP-dependent, type I                                                                                                                                                        ((PKG, 5),)
# PTGS2      PTGS2  prostaglandin-endoperoxide synthase 2 (prostaglandin G/H synthase and cyclooxygenase)                                                                                     ((Cyclooxygenase 2, 1), (Cyclooxygenase 2 (COX2), 2.2), (COX2, 3), (COX2, 10))
# PTK2        PTK2                                                              protein tyrosine kinase 2                                                                                                                                                        ((FAK, 5),)
# QRFPR      QRFPR                                              pyroglutamylated RFamide peptide receptor                                                                                                                                                   ((GPR103, 2.2),)
# ROCK1      ROCK1                                Rho-associated, coiled-coil containing protein kinase 1                                                                                                                                                       ((ROCK, 5),)
# ROCK2      ROCK2                                Rho-associated, coiled-coil containing protein kinase 2                                                                                                                                                       ((ROCK, 5),)
# SCN5A      SCN5A                                    sodium channel, voltage gated, type V alpha subunit                       ((Voltage-gated sodium channel subunit α Nav1.5, 1), (Na channel (site 2), 2.1), (Nav1.5, 2.2), (Na+ site 2, 3), (INa, 4), (Na+ site 2, 10))
# SLC10A1  SLC10A1                    solute carrier family 10 (sodium/bile acid cotransporter), member 1                                                                                                                                  ((NTCP, 6), (NTCP, 7), (NTCP, 8))
# SLC10A2  SLC10A2                    solute carrier family 10 (sodium/bile acid cotransporter), member 2                                                                                                                                             ((ASBT, 6), (ASBT, 7))
# SLC15A2  SLC15A2                          solute carrier family 15 (oligopeptide transporter), member 2                                                                                               ((solute carrier family 15 (H+/peptide transporter), member 2, 11),)
# SLC22A1  SLC22A1                        solute carrier family 22 (organic cation transporter), member 1                                                                      ((OCTs, 7), (OCT1, 8), (solute carrier family 22 (organic cation transporter), member 1, 11))
# SLC22A2  SLC22A2                        solute carrier family 22 (organic cation transporter), member 2                                                                                           ((solute carrier family 22 (organic cation transporter), member 2, 11),)
# SLC22A6  SLC22A6                         solute carrier family 22 (organic anion transporter), member 6                                                                                            ((solute carrier family 22 (organic anion transporter), member 6, 11),)
# SLC22A7  SLC22A7                         solute carrier family 22 (organic anion transporter), member 7                                                                                                                                             ((OATs, 7), (OAT2, 8))
# SLC22A9  SLC22A9                         solute carrier family 22 (organic anion transporter), member 9                                                                                                                                             ((OATs, 7), (OAT7, 8))
# SLC29A1  SLC29A1              solute carrier family 29 (equilibrative nucleoside transporter), member 1                                                                              ((Adenosine Transporter, 2.1), (Adenosine transporter (AdT, ENT1), 2.2), (ENT1/2, 8))
# SLC29A2  SLC29A2              solute carrier family 29 (equilibrative nucleoside transporter), member 2                                                                                                                                                     ((ENT1/2, 8),)
# SLC47A1  SLC47A1                     solute carrier family 47 (multidrug and toxin extrusion), member 1                                                                                                                                                      ((MATE1, 8),)
# SLC47A2  SLC47A2                     solute carrier family 47 (multidrug and toxin extrusion), member 2                                                                                                                                                    ((MATE2-K, 8),)
# SLC4A2    SLC4A2                                    solute carrier family 4 (anion exchanger), member 2                                                                                                                                                        ((AE2, 7),)
# SLC51A    SLC51A                                                solute carrier family 51, alpha subunit                                                                                                                                      ((OSTα/OSTβ, 6), (OSTα/β, 8))
# SLC51B    SLC51B                                                 solute carrier family 51, beta subunit                                                                                                                                      ((OSTα/OSTβ, 6), (OSTα/β, 8))
# SLC6A2    SLC6A2                       solute carrier family 6 (neurotransmitter transporter), member 2                                                                           ((Noradrenaline transporter, 1), (NE transporter, 2.1), (NET, 2.2), (NE transporter, 3))
# SLC6A4    SLC6A4                       solute carrier family 6 (neurotransmitter transporter), member 4                                                                                                   ((Serotonin transporter, 1), (5HTT, 2.2), (5-HT transporter, 3))
# SLCO1A2  SLCO1A2                            solute carrier organic anion transporter family, member 1A2                                                                                                                                         ((OATPs, 7), (OATP1A2, 8))
# SLCO1B1  SLCO1B1                            solute carrier organic anion transporter family, member 1B1                                                                      ((OATPs, 7), (OATP1B1, 8), (solute carrier organic anion transporter family, member 1B1, 11))
# SLCO1B3  SLCO1B3                            solute carrier organic anion transporter family, member 1B3                                                                      ((OATPs, 7), (OATP1B3, 8), (solute carrier organic anion transporter family, member 1B3, 11))
# SLCO2B1  SLCO2B1                            solute carrier organic anion transporter family, member 2B1                                                                                                                                         ((OATPs, 7), (OATP2B1, 8))
# STK11      STK11                                                             serine/threonine kinase 11                                                                                                                                                       ((LKB1, 5),)
# SULT1A1  SULT1A1                    sulfotransferase family, cytosolic, 1A, phenol-preferring, member 1                                                                                       ((sulfotransferase family, cytosolic, 1A, phenol-preferring, member 1, 11),)
# TBXA2R    TBXA2R                                                                thromboxane A2 receptor                                                                                                         ((Thromboxane A2 TP, 2.1), (Thromboxane A2 (TBXA2R), 2.2))
# TH            TH                                                                   tyrosine hydroxylase                                                                                                                                       ((tyrosine hydroxylase, 3),)
# TPMT        TPMT                                                         thiopurine S-methyltransferase                                                                                                                            ((thiopurine S-methyltransferase, 11),)
# UGT1A1    UGT1A1                                   UDP glucuronosyltransferase 1 family, polypeptide A1                                                                                                      ((UDP glucuronosyltransferase 1 family, polypeptide A1, 11),)
# UGT2B15  UGT2B15                                  UDP glucuronosyltransferase 2 family, polypeptide B15                                                                                                     ((UDP glucuronosyltransferase 2 family, polypeptide B15, 11),)
# UGT2B17  UGT2B17                                  UDP glucuronosyltransferase 2 family, polypeptide B17                                                                                                     ((UDP glucuronosyltransferase 2 family, polypeptide B17, 11),)
# UGT2B7    UGT2B7                                   UDP glucuronosyltransferase 2 family, polypeptide B7                                                                                                      ((UDP glucuronosyltransferase 2 family, polypeptide B7, 11),)
# UTS2R      UTS2R                                                                   urotensin 2 receptor                                                                                                                                     ((Urotensin II, 2.2), (UT, 3))
# VDR          VDR                                         vitamin D (1,25- dihydroxyvitamin D3) receptor                                                                                                                                                        ((VDR, 9),)

# %%
# Save/restore...

symbols.to_pickle('unique_symbols.pkl')

# %%
# symbols = pd.read_pickle('unique_symbols.pkl')

# %%
# Write table to RDBMS...

tmp = symbols.copy()

tmp['targets'] = tmp['targets'].apply(lambda x: u'|'.join(u'{};{}'.format(y, z) for y, z in x).encode('ascii', 'xmlcharrefreplace')) # Convert 'targets' to string representation
 
# Write to database...

col_types = {
    'symbol':        VARCHAR2(10),
    'approved_name': VARCHAR2(1000),
    'targets':       VARCHAR2(1000)
}

tmp.to_sql('tt_symbols', engine, if_exists='replace', index=False, dtype=col_types)

del tmp

# %% [markdown]
# ### Check overlap of targets
#
# Here, 'targets' is used to mean the targets from the literature, however they may have been specified (and _not_ ChEMBL targets).
#
# Thus, a target specified as 'AKT1, 2 or 3' clearly overlaps with 'PKBa (AKT1)'.

# %%
def f(x):
    
    symbols = x['symbol'].values
        
    return pd.Series({'symbols': symbols, 'count': len(symbols)})

df2 = df1.groupby(['target', 'table']).apply(f).reset_index()

# %%
# Get targets where there is a 'non-trivial' overlap of symbols...

def f(x, y):
    
    s0, s1 = set(x['symbols']), set(y['symbols'])
    
    if (not s0.intersection(s1) or (s0 == s1) or (len(s0) == 1 and len(s1) == 1)): return ''

    return pd.DataFrame([x, y]).to_html()

html = ''.join(f(x, y) for x, y in ((x[1], y[1]) for x, y in combinations(df2.iterrows(), 2)))
    
HTML(html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>target</th>
#       <th>table</th>
#       <th>count</th>
#       <th>symbols</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>20</th>
#       <td>AKT1, 2 or 3</td>
#       <td>5</td>
#       <td>3</td>
#       <td>[AKT1, AKT2, AKT3]</td>
#     </tr>
#     <tr>
#       <th>213</th>
#       <td>PKBa (AKT1)</td>
#       <td>2.2</td>
#       <td>1</td>
#       <td>[AKT1]</td>
#     </tr>
#   </tbody>
# </table><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>target</th>
#       <th>table</th>
#       <th>count</th>
#       <th>symbols</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>35</th>
#       <td>Acetylcholine receptor subunit α1 or α4</td>
#       <td>1</td>
#       <td>2</td>
#       <td>[CHRNA1, CHRNA4]</td>
#     </tr>
#     <tr>
#       <th>189</th>
#       <td>Nicotinic acetylcholine</td>
#       <td>2.1</td>
#       <td>1</td>
#       <td>[CHRNA1]</td>
#     </tr>
#   </tbody>
# </table><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>target</th>
#       <th>table</th>
#       <th>count</th>
#       <th>symbols</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>35</th>
#       <td>Acetylcholine receptor subunit α1 or α4</td>
#       <td>1</td>
#       <td>2</td>
#       <td>[CHRNA1, CHRNA4]</td>
#     </tr>
#     <tr>
#       <th>190</th>
#       <td>Nicotinic receptor (central)</td>
#       <td>2.2</td>
#       <td>1</td>
#       <td>[CHRNA1]</td>
#     </tr>
#   </tbody>
# </table><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>target</th>
#       <th>table</th>
#       <th>count</th>
#       <th>symbols</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>43</th>
#       <td>Adenosine Transporter</td>
#       <td>2.1</td>
#       <td>1</td>
#       <td>[SLC29A1]</td>
#     </tr>
#     <tr>
#       <th>91</th>
#       <td>ENT1/2</td>
#       <td>8</td>
#       <td>2</td>
#       <td>[SLC29A1, SLC29A2]</td>
#     </tr>
#   </tbody>
# </table><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>target</th>
#       <th>table</th>
#       <th>count</th>
#       <th>symbols</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>45</th>
#       <td>Adenosine transporter (AdT, ENT1)</td>
#       <td>2.2</td>
#       <td>1</td>
#       <td>[SLC29A1]</td>
#     </tr>
#     <tr>
#       <th>91</th>
#       <td>ENT1/2</td>
#       <td>8</td>
#       <td>2</td>
#       <td>[SLC29A1, SLC29A2]</td>
#     </tr>
#   </tbody>
# </table><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>target</th>
#       <th>table</th>
#       <th>count</th>
#       <th>symbols</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>72</th>
#       <td>CDK2A</td>
#       <td>2.2</td>
#       <td>1</td>
#       <td>[CDK2]</td>
#     </tr>
#     <tr>
#       <th>73</th>
#       <td>CDKs</td>
#       <td>5</td>
#       <td>2</td>
#       <td>[CDK2, CDK4]</td>
#     </tr>
#   </tbody>
# </table><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>target</th>
#       <th>table</th>
#       <th>count</th>
#       <th>symbols</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>93</th>
#       <td>ERK1/2</td>
#       <td>5</td>
#       <td>2</td>
#       <td>[MAPK3, MAPK1]</td>
#     </tr>
#     <tr>
#       <th>94</th>
#       <td>ERK2 (P42mapk)</td>
#       <td>10</td>
#       <td>1</td>
#       <td>[MAPK1]</td>
#     </tr>
#   </tbody>
# </table><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>target</th>
#       <th>table</th>
#       <th>count</th>
#       <th>symbols</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>110</th>
#       <td>GSK3a</td>
#       <td>10</td>
#       <td>1</td>
#       <td>[GSK3A]</td>
#     </tr>
#     <tr>
#       <th>112</th>
#       <td>GSK3α/β</td>
#       <td>5</td>
#       <td>2</td>
#       <td>[GSK3A, GSK3B]</td>
#     </tr>
#   </tbody>
# </table><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>target</th>
#       <th>table</th>
#       <th>count</th>
#       <th>symbols</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>111</th>
#       <td>GSK3a</td>
#       <td>3</td>
#       <td>1</td>
#       <td>[GSK3A]</td>
#     </tr>
#     <tr>
#       <th>112</th>
#       <td>GSK3α/β</td>
#       <td>5</td>
#       <td>2</td>
#       <td>[GSK3A, GSK3B]</td>
#     </tr>
#   </tbody>
# </table><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>target</th>
#       <th>table</th>
#       <th>count</th>
#       <th>symbols</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>130</th>
#       <td>IKs</td>
#       <td>4</td>
#       <td>1</td>
#       <td>[KCNQ1]</td>
#     </tr>
#     <tr>
#       <th>222</th>
#       <td>Potassium voltage-gated channel KQT-like member 1 and minimal potassium channel MinK</td>
#       <td>1</td>
#       <td>2</td>
#       <td>[KCNQ1, KCNE1]</td>
#     </tr>
#   </tbody>
# </table><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>target</th>
#       <th>table</th>
#       <th>count</th>
#       <th>symbols</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>140</th>
#       <td>KCNQ1</td>
#       <td>2.2</td>
#       <td>1</td>
#       <td>[KCNQ1]</td>
#     </tr>
#     <tr>
#       <th>222</th>
#       <td>Potassium voltage-gated channel KQT-like member 1 and minimal potassium channel MinK</td>
#       <td>1</td>
#       <td>2</td>
#       <td>[KCNQ1, KCNE1]</td>
#     </tr>
#   </tbody>
# </table><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>target</th>
#       <th>table</th>
#       <th>count</th>
#       <th>symbols</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>193</th>
#       <td>OAT2</td>
#       <td>8</td>
#       <td>1</td>
#       <td>[SLC22A7]</td>
#     </tr>
#     <tr>
#       <th>200</th>
#       <td>OATs</td>
#       <td>7</td>
#       <td>2</td>
#       <td>[SLC22A7, SLC22A9]</td>
#     </tr>
#   </tbody>
# </table><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>target</th>
#       <th>table</th>
#       <th>count</th>
#       <th>symbols</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>194</th>
#       <td>OAT7</td>
#       <td>8</td>
#       <td>1</td>
#       <td>[SLC22A9]</td>
#     </tr>
#     <tr>
#       <th>200</th>
#       <td>OATs</td>
#       <td>7</td>
#       <td>2</td>
#       <td>[SLC22A7, SLC22A9]</td>
#     </tr>
#   </tbody>
# </table><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>target</th>
#       <th>table</th>
#       <th>count</th>
#       <th>symbols</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>195</th>
#       <td>OATP1A2</td>
#       <td>8</td>
#       <td>1</td>
#       <td>[SLCO1A2]</td>
#     </tr>
#     <tr>
#       <th>199</th>
#       <td>OATPs</td>
#       <td>7</td>
#       <td>4</td>
#       <td>[SLCO1A2, SLCO1B1, SLCO1B3, SLCO2B1]</td>
#     </tr>
#   </tbody>
# </table><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>target</th>
#       <th>table</th>
#       <th>count</th>
#       <th>symbols</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>196</th>
#       <td>OATP1B1</td>
#       <td>8</td>
#       <td>1</td>
#       <td>[SLCO1B1]</td>
#     </tr>
#     <tr>
#       <th>199</th>
#       <td>OATPs</td>
#       <td>7</td>
#       <td>4</td>
#       <td>[SLCO1A2, SLCO1B1, SLCO1B3, SLCO2B1]</td>
#     </tr>
#   </tbody>
# </table><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>target</th>
#       <th>table</th>
#       <th>count</th>
#       <th>symbols</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>197</th>
#       <td>OATP1B3</td>
#       <td>8</td>
#       <td>1</td>
#       <td>[SLCO1B3]</td>
#     </tr>
#     <tr>
#       <th>199</th>
#       <td>OATPs</td>
#       <td>7</td>
#       <td>4</td>
#       <td>[SLCO1A2, SLCO1B1, SLCO1B

# %% [markdown]
# ### Targets corresponding to multiple symbols
#
# Again, here 'targets' means the targets mentioned in the literature and not, _e.g._ ChEMBL targets.

# %%
def f(x):
    
    symbols = x['symbol'].values
        
    return pd.DataFrame({'symbols': [symbols], 'count': [len(symbols)]}) # A DataFrame is required in this case: because of the complex groupby key, maybe?

symbols_by_target = symbols.groupby('targets').apply(f).reset_index(1, drop=True).reset_index()

symbols_by_target.query("count > 1").sort('count', ascending=False)
# Out:
#                                            targets  count                                                           symbols
# 19   ((ATPase (Na+/K+), 3), (ATPase (Na+/K+), 10))      8  [ATP1A1, ATP1A2, ATP1A3, ATP1A4, ATP1B1, ATP1B2, ATP1B3, ATP1B4]
# 74                                     ((IKP, 4),)      4                                      [KCNK1, KCNK3, KCNK4, KCNK6]
# 32                          ((Aurora kinases, 5),)      3                                             [AURKA, AURKB, AURKC]
# 78                                   ((Ito,s, 4),)      3                                             [KCNA4, KCNA7, KCNC4]
# 145                                 ((VEGFRs, 5),)      3                                                 [FLT1, FLT4, KDR]
# 62                              ((GRK2, GRK5, 5),)      2                                                    [ADRBK1, GRK5]
# 71                                   ((ICa,T, 4),)      2                                                [CACNA1G, CACNA1H]
# 72                                     ((IK1, 4),)      2                                                   [KCNJ12, KCNJ2]
# 73                                   ((IKAch, 4),)      2                                                    [KCNJ3, KCNJ5]
# 13                                    ((AMPK, 5),)      2                                                  [PRKAA1, PRKAA2]
# 75                                    ((IKur, 4),)      2                                                    [KCNA5, KCNC1]
# 76                                      ((If, 4),)      2                                                      [HCN2, HCN4]
# 77                                   ((Ito,f, 4),)      2                                                    [KCND2, KCND3]
# 14                                   ((ANF, 2.2),)      2                                                      [NPR1, NPR2]
# 95                               ((MT3 (ML2), 3),)      2                                                  [MTNR1A, MTNR1B]
# 115                  ((OSTα/OSTβ, 6), (OSTα/β, 8))      2                                                  [SLC51A, SLC51B]
# 116                                 ((PDGFRs, 5),)      2                                                  [PDGFRA, PDGFRB]
# 134                                   ((ROCK, 5),)      2                                                    [ROCK1, ROCK2]
# 12                            ((AKT1, 2 or 3, 5),)      2                                                      [AKT2, AKT3]

# %% [markdown]
# In Most of these literature targets corresponding to multipe gene symbols are simply families of isoforms, _e.g._ 'Aurora kinases' = AURKA, AURKB and AURKC, or 'VEGFRs' = FLT1, FLT4 and KDR.
#
# However, in the case of the Ion Channels (from Table 4), this is not always the case. Here, products of more than one gene may contribute to a given current: for example, both [KCNA4](https://en.wikipedia.org/wiki/KCNA4) and [KCNA7](https://en.wikipedia.org/wiki/KCNA7) contribute to I<sub>to,s</sub>.
#
# Whether, in all cases, one isoform can be identified as the 'primary' member of the family and therefore, for simplicity, identified with the current itself isn't clear.
#
# This is something of an issue as the assumption is made elsewhere that there is always a gene-to-target mapping, _i.e._ that each target may be identified with a single gene.
#
# One reason for doing this is to have an unambiguous nomenclature for the targets, as gene names are standardised (by HUGO). The names of multi-component entities, by contrast, seem to be less standardised.
#
# The simple one-to-one mapping obviously holds in many simple cases, such as most enzymes (note that it is not an issue if various members of a family are included).
#
# In cases of complexes it is obviously a simplification; however, the hope is that, in most cases, there will be one central, active unit (_i.e._ one that ligands would interact with) that many stand for the complex as a whole.
#
# Whether cases, like the ion channels, where several members of a family actually contribute to the activity may be treated this way remains to be seen.
