# %% [markdown]
# # Compound  Counts
#
# Count distinct parent compounds

# %%
from local_utils.file_utils import backup_file

# %% [markdown]
# ### Configuration

# %%
# ChEMBL connection...

engine = create_engine(open('database.txt').read().strip())

# %%
# Maximum number of heavy atoms allowed...

max_nat = 50

# %% [markdown]
# ### Reload targets

# %%
targets = pd.read_pickle('chembl_targets.pkl')

targets.shape[0], targets.query("exclude == 1").shape[0]
# Out:
# (377, 19)

# %%
targets.head()
# Out:
#    symbol                                            approved_name                                                                  targets  n_target      chembl_id     target_type                       pref_name species  exclude                            target_class_0                            target_class_1
# 0   ABCB1   ATP-binding cassette, sub-family B (MDR/TAP), member 1  MDR1;7|MDR1;8|ATP-binding cassette, sub-family B (MDR/TAP), member 1;11         1     CHEMBL4302  SINGLE PROTEIN                P-glycoprotein 1   Human        0  Transporter > Primary active transporter  Transporter > Primary active transporter
# 1   ABCB1   ATP-binding cassette, sub-family B (MDR/TAP), member 1  MDR1;7|MDR1;8|ATP-binding cassette, sub-family B (MDR/TAP), member 1;11         1  CHEMBL1075229  SINGLE PROTEIN  Multidrug resistance protein 1     Rat        0                                       N/A                                       N/A
# 2  ABCB11  ATP-binding cassette, sub-family B (MDR/TAP), member 11                                                     BSEP;6|BSEP;7|BSEP;8         1     CHEMBL6020  SINGLE PROTEIN           Bile salt export pump   Human        0  Transporter > Primary active transporter  Transporter > Primary active transporter
# 3  ABCB11  ATP-binding cassette, sub-family B (MDR/TAP), member 11                                                     BSEP;6|BSEP;7|BSEP;8         1  CHEMBL2073674  SINGLE PROTEIN           Bile salt export pump     Rat        0                                       N/A                                       N/A
# 4   ABCB4   ATP-binding cassette, sub-family B (MDR/TAP), member 4                                                            MDR3;7|MDR3;8         1  CHEMBL1743129  SINGLE PROTEIN  Multidrug resistance protein 3   Human        0  Transporter > Primary active transporter  Transporter > Primary active transporter

# %% [markdown]
# ## Get counts for distinct parent compounds

# %% [markdown]
# ### Individual ChEMBL targets
#
# Aggregate at ChEMBL target level.
#
# Note that, at this stage, multiple target_chemblid to symbol mappings have not been pruned, hence the 'select distinct'.

# %%
count_by_target = pd.read_sql_query("""
select
    a.symbol
  , a.species
  , a.target_chemblid
  , count(distinct case when a.active = 1 then a.parent_cmpd_chemblid end) as n_active
  , count(distinct a.parent_cmpd_chemblid) as n_total
from
  tt_curve_data_v2 a 
where
    a.exclude = 0
and a.nat <= :max_nat 
group by
    a.symbol
  , a.species
  , a.target_chemblid
order by
    a.symbol
  , a.species
  , a.target_chemblid
""", engine, params={'max_nat': max_nat})

count_by_target.shape
# Out:
# (312, 5)

# %%
count_by_target
# Out:
#       symbol species target_chemblid  n_active  n_total
# 0      ABCB1   Human      CHEMBL4302       784     1249
# 1     ABCB11   Human      CHEMBL6020         1       16
# 2     ABCB11     Rat   CHEMBL2073674         8        9
# 3      ABCC2   Human      CHEMBL5748         5       27
# 4      ABCC2     Rat   CHEMBL2073676        14       55
# 5      ABCC3   Human      CHEMBL5918         1        1
# 6      ABCC3     Rat   CHEMBL2073682         1        4
# 7      ABCC4   Human   CHEMBL1743128         8       21
# 8      ABCG2   Human      CHEMBL5393       266      379
# 9       ABL1   Human      CHEMBL1862       978     1828
# 10       ACE   Human      CHEMBL1808       465      653
# 11       ACE     Rat      CHEMBL2625       294      359
# 12      ACHE   Human       CHEMBL220      2030     4099
# 13      ACHE     Rat      CHEMBL3199       729     1033
# 14     ADCY5   Human      CHEMBL3189        23       83
# 15     ADCY5     Rat      CHEMBL2880        18       22
# 16    ADORA1   Human       CHEMBL226      3036     4483
# 17    ADORA1     Rat       CHEMBL318      2270     2957
# 18   ADORA2A   Human       CHEMBL251      3364     5099
# 19   ADORA2A     Rat       CHEMBL302      1387     1744
# 20   ADORA2B   Human       CHEMBL255      1602     2366
# 21   ADORA2B     Rat      CHEMBL2592        37       53
# 22    ADORA3   Human       CHEMBL256      2951     4365
# 23    ADORA3     Rat      CHEMBL3360       260      379
# 24    ADRA1A   Human       CHEMBL229      1160     1255
# 25    ADRA1A     Rat       CHEMBL319       467      528
# 26    ADRA1B   Human       CHEMBL232       908     1108
# 27    ADRA1B     Rat       CHEMBL315       199      933
# 28    ADRA1D   Human       CHEMBL223       862     1678
# 29    ADRA1D     Rat       CHEMBL326       511     1282
# 30    ADRA2A   Human      CHEMBL1867       660     1481
# 31    ADRA2A     Rat       CHEMBL327        41       77
# 32    ADRA2B   Human      CHEMBL1942       384     1118
# 33    ADRA2B     Rat       CHEMBL266        47       50
# 34    ADRA2C   Human      CHEMBL1916       499     1253
# 35    ADRA2C     Rat       CHEMBL314         4        4
# 36     ADRB1   Human       CHEMBL213      1131     2225
# 37     ADRB1     Rat      CHEMBL3252        90      183
# 38     ADRB2   Human       CHEMBL210      1290     3789
# 39     ADRB2     Rat      CHEMBL3754        41       65
# 40     ADRB3   Human       CHEMBL246      1356     2208
# 41     ADRB3     Rat      CHEMBL4031        33       38
# 42    ADRBK1   Human      CHEMBL4079        75      121
# 43     AGTR1   Human       CHEMBL227       567     1001
# 44     AGTR1     Rat       CHEMBL329        73      150
# 45       AHR   Human      CHEMBL3201       172      428
# 46       AHR     Rat      CHEMBL5400         1        1
# 47      AKT1   Human      CHEMBL4282      1289     2279
# 48      AKT2   Human      CHEMBL2431       525     1279
# 49      AKT3   Human      CHEMBL4816       313     1055
# 50     APLNR   Human   CHEMBL1628481        15       91
# 51        AR   Human      CHEMBL1871      1432     2335
# 52        AR     Rat      CHEMBL3072       304     1181
# 53     AURKA   Human      CHEMBL4722      1766     2888
# 54     AURKB   Human      CHEMBL2185      1479     2182
# 55     AURKC   Human      CHEMBL3935        77      131
# 56    AVPR1A   Human      CHEMBL1889       550     1462
# 57    AVPR1A     Rat      CHEMBL2868       251      280
# 58    AVPR1B   Human      CHEMBL1921       229      669
# 59    AVPR1B     Rat      CHEMBL2659        27       31
# 60    BDKRB1   Human      CHEMBL4308       659      716
# 61    BDKRB1     Rat      CHEMBL4613        34       34
# 62    BDKRB2   Human      CHEMBL3157       348     1216
# 63    BDKRB2     Rat      CHEMBL2501        20       46
# 64      BRAF   Human      CHEMBL5145       544      764
# 65       CA2   Human       CHEMBL205      3746     5000
# 66       CA2     Rat      CHEMBL4706         1        1
# 67   CACNA1C   Human      CHEMBL1940        62      119
# 68   CACNA1C     Rat      CHEMBL3762        81      110
# 69   CACNA1G   Human      CHEMBL4641       250      291
# 70   CACNA1H   Human      CHEMBL1859        73     1062
# 71     CALCR   Human      CHEMBL1832         1      791
# 72     CALCR   Human   CHEMBL2111189         1        1
# 73     CALCR   Human   CHEMBL2111190         1        1
# 74    CALCRL   Human   CHEMBL2107838        60       62
# 75    CALCRL   Human   CHEMBL2109232         0        1
# 76    CALCRL   Human   CHEMBL2111191         1        1
# 77    CALCRL   Human      CHEMBL3798       562      592
# 78    CALCRL     Rat      CHEMBL4755         7        9
# 79    CAMK2A   Human      CHEMBL4147        89      392
# 80      CDK2   Human   CHEMBL1907605       307      418
# 81      CDK2   Human   CHEMBL2094126       594      801
# 82      CDK2   Human   CHEMBL2094128       865     1241
# 83      CDK2   Human       CHEMBL301      1523     2748
# 84      CDK2   Human   CHEMBL3038469        88      168
# 85      CDK2   Human   CHEMBL3038470         2        2
# 86      CDK4   Human   CHEMBL1907601       539      851
# 87      CDK4   Human   CHEMBL2095942       141      155
# 88      CDK4   Human   CHEMBL3038472         0        1
# 89      CDK4   Human   CHEMBL3301385         0        1
# 90      CDK4   Human       CHEMBL331       381      621
# 91     CHRM1   Human       CHEMBL216      1323     2588
# 92     CHRM1     Rat       CHEMBL276      1212     1685
# 93     CHRM2   Human       CHEMBL211      1238     2290
# 94     CHRM2     Rat       CHEMBL309       405      505
# 95     CHRM3   Human       CHEMBL245      1254     2288
# 96     CHRM3     Rat       CHEMBL320       165      247
# 97     CHRM4   Human      CHEMBL1821       473     1430
# 98     CHRM4     Rat       CHEMBL317        40       76
# 99    CHRNA1   Human   CHEMBL1907588        47      137
# 100   CHRNA1   Human      CHEMBL4808        12       29
# 101   CHRNA4   Human      CHEMBL1882       138      153
# 102   CHRNA4   Human   CHEMBL1907589       730     1023
# 103   CHRNA4   Human   CHEMBL1907591        24       65
# 104   CHRNA4   Human   CHEMBL3038461        10       13
# 105   CHRNA4     Rat   CHEMBL1907595       138      180
# 106   CHRNA4     Rat   CHEMBL1907596      1221     1510
# 107   CHRNA4     Rat       CHEMBL307       126      176
# 108   CYP1A1   Human      CHEMBL2231        99      120
# 109   CYP1A1     Rat      CHEMBL2922        12       25
# 110   CYP1A2   Human      CHEMBL3356      6174    18307
# 111   CYP1A2     Rat   CHEMBL1075125         0        1
# 112   CYP2A6   Human      CHEMBL5282        81      967
# 113   CYP2B6   Human      CHEMBL4729        40      194
# 114  CYP2C19   Human      CHEMBL3622      6455    18313
# 115   CYP2C8   Human      CHEMBL3721        68      206
# 116   CYP2C9   Human      CHEMBL3397      5763    18939
# 117   CYP2D6   Human       CHEMBL289      4180    20053
# 118   CYP2E1   Human      CHEMBL5281        21      884
# 119   CYP2E1     Rat      CHEMBL5978         4       17
# 120   CYP3A4   Human       CHEMBL340      7779    22706
# 121   CYP3A5   Human      CHEMBL3019        12       31
# 122     DMPK   Human      CHEMBL5320        25       90
# 123     DPYD   Human      CHEMBL3172         6        6
# 124     DRD1   Human      CHEMBL2056       739     2065
# 125     DRD1     Rat       CHEMBL265       601      973
# 126     DRD2   Human       CHEMBL217      4155     6054
# 127     DRD2     Rat       CHEMBL339      3493     4447
# 128     DRD4   Human       CHEMBL219      1792     2802
# 129     DRD4     Rat      CHEMBL3361       125      134
# 130    EDNRA   Human       CHEMBL252      1201     2085
# 131    EDNRA     Rat      CHEMBL4566       770      865
# 132    EDNRB   Human      CHEMBL1785       802     1178
# 133    EDNRB     Rat      CHEMBL4631       111      188
# 134     EGFR   Human       CHEMBL203      3509     6354
# 135    ERBB2   Human      CHEMBL1824      1304     3061
# 136    ERBB2     Rat      CHEMBL3848        13       13
# 137     ESR1   Human       CHEMBL206      1673     3770
# 138     ESR1     Rat      CHEMBL2724        47       50
# 139     ESR2   Human       CHEMBL242      1651     3028
# 140     ESR2     Rat      CHEMBL3021        43       48
# 141       F2   Human       CHEMBL204      3755     6041
# 142       F2     Rat      CHEMBL3078        10       13
# 143     FLT1   Human      CHEMBL1868       915     2516
# 144     FLT4   Human      CHEMBL1955       536      994
# 145     GCGR   Human      CHEMBL1985       697      789
# 146     GCGR     Rat      CHEMBL4720        18       18
# 147     GHSR   Human      CHEMBL4616      1106     1211
# 148     GHSR     Rat      CHEMBL3278        38       55
# 149    GRIN1   Human   CHEMBL1907603       171      207
# 150    GRIN1   Human   CHEMBL1907604        66      106
# 151    GRIN1   Human      CHEMBL2015        77       84
# 152    GRIN1     Rat   CHEMBL2096666       163      300
# 153    GRIN1     Rat   CHEMBL2096680        51      284
# 154    GRIN1     Rat   CHEMBL2096911       101      333
# 155    GRIN1     Rat   CHEMBL3038506        33       41
# 156    GRIN1     Rat       CHEMBL330       473      683
# 157     GRK5   Human      CHEMBL5678       132      400
# 158    GSK3A   Human      CHEMBL2850       658     1356
# 159    GSK3B   Human       CHEMBL262      2239     3350
# 160    GSK3B     Rat      CHEMBL3669        17       17
# 161    GSTM1   Human      CHEMBL2081         3       15
# 162    GSTP1   Human      CHEMBL3902        40       83
# 163    GSTT1     Rat      CHEMBL2423         1        1
# 164     HCN2   Human   CHEMBL1795172         1        1
# 165     HCN4   Human   CHEMBL1250417        22       42
# 166    HNF4A   Human      CHEMBL5398         7      236
# 167     HRH1   Human       CHEMBL231       918     1917
# 168     HRH1     Rat      CHEMBL4701       114      154
# 169     HRH2   Human      CHEMBL1941       245     1121
# 170     HRH2     Rat      CHEMBL4654         5       37
# 171     HRH3   Human       CHEMBL264      2928     3141
# 172     HRH3     Rat      CHEMBL4124      1306     1381
# 173    HTR1B   Human      CHEMBL1898       924     1096
# 174    HTR1B     Rat      CHEMBL3459       284     1162
# 175    HTR2A   Human       CHEMBL224      2388     3386
# 176    HTR2A     Rat       CHEMBL322      1378     1683
# 177    HTR2B   Human      CHEMBL1833       953     1793
# 178    HTR2B     Rat       CHEMBL323       130      135
# 179    HTR2C   Human       CHEMBL225      2183     3387
# 180    HTR2C     Rat       CHEMBL324       457      608
# 181     HTR4   Human      CHEMBL1875       329      365
# 182     HTR4     Rat      CHEMBL4317       162      245
# 183     HTR7   Human      CHEMBL3155      1130     1346
# 184     HTR7     Rat      CHEMBL3223       298      331
# 185     JAK2   Human      CHEMBL2971      1343     2181
# 186    KCNA4   Human      CHEMBL4205         4        5
# 187    KCNA5   Human      CHEMBL4306       521      602
# 188    KCNC1   Human      CHEMBL5529         0        4
# 189    KCNC1     Rat   CHEMBL2321617         1        2
# 190    KCND2     Rat   CHEMBL1075227         4        7
# 191    KCND3   Human      CHEMBL1964         3        4
# 192    KCNH2   Human       CHEMBL240      3798     8084
# 193   KCNJ11   Human      CHEMBL1886        45       54
# 194   KCNJ11   Human   CHEMBL2095198        15       21
# 195   KCNJ11   Human   CHEMBL2096972        26       39
# 196    KCNJ2   Human   CHEMBL1914276         0        3
# 197    KCNK3   Human   CHEMBL2321613         1        1
# 198    KCNQ1   Human      CHEMBL1866        30       67
# 199    KCNQ1   Human   CHEMBL2221347        25       56
# 200      KDR   Human       CHEMBL279      4505     6209
# 201      KIT   Human      CHEMBL1936       800     1464
# 202      LTK   Human      CHEMBL5627       185      402
# 203     MAOA   Human      CHEMBL1951       714     2294
# 204     MAOA     Rat      CHEMBL3358       529      986
# 205   MAP3K5   Human      CHEMBL5285        51      170
# 206    MAPK1   Human      CHEMBL4040      3847    15251
# 207    MAPK1     Rat      CHEMBL5233        11       28
# 208    MAPK3   Human      CHEMBL3385        56      989
# 209     MLNR   Human      CHEMBL2203       247      286
# 210   MTNR1A   Human      CHEMBL1945       678      767
# 211   MTNR1B   Human      CHEMBL1946       610      645
# 212   MTNR1B     Rat      CHEMBL2566         1        1
# 213     MTOR   Human      CHEMBL2842      1351     4748
# 214     MTOR     Rat   CHEMBL1075134        30       30
# 215     NAT1   Human      CHEMBL5101        27       48
# 216   NFE2L2   Human   CHEMBL1075094         4    84881
# 217     NOS3   Human      CHEMBL4803       290      772
# 218     NOS3     Rat   CHEMBL1075230         6        8
# 219     NPR1   Human      CHEMBL1988         2        2
# 220    NPY1R   Human      CHEMBL4777       575     1693
# 221    NPY1R     Rat      CHEMBL2587         2        4
# 222    NR0B2   Human      CHEMBL5603         4        4
# 223    NR1H2   Human      CHEMBL4093       567      729
# 224    NR1H3   Human      CHEMBL2808       538      664
# 225    NR1H4   Human      CHEMBL2047       503     1132
# 226    NR1I2   Human      CHEMBL3401       122      379
# 227    NR1I2     Rat   CHEMBL2146315         0      398
# 228    NR1I3   Human      CHEMBL5503         0        3
# 229    NR3C1   Human      CHEMBL2034      1860     3328
# 230    NR3C1     Rat      CHEMBL3368       107      132
# 231    NR5A2   Human      CHEMBL3544        47      292
# 232    OPRD1   Human       CHEMBL236      2534     4622
# 233    OPRD1     Rat       CHEMBL269      1182     1443
# 234    OPRK1   Human       CHEMBL237      2972     4475
# 235    OPRK1     Rat      CHEMBL3614       170      244
# 236    OPRM1   Human       CHEMBL233      2810     4838
# 237    OPRM1     Rat       CHEMBL270      1748     2020
# 238    PDE3A   Human       CHEMBL241       181      341
# 239    PDE3B   Human       CHEMBL290        95      118
# 240   PDGFRA   Human      CHEMBL2007       369      653
# 241   PDGFRB   Human      CHEMBL1913       831     1380
# 242   PDGFRB     Rat      CHEMBL4125        17       22
# 243    PDPK1   Human      CHEMBL2534       376     1089
# 244   PIK3CA   Human   CHEMBL2111367       123      139
# 245   PIK3CA   Human      CHEMBL4005      2074     2651
# 246   PIK3CG   Human      CHEMBL3267      1118     1475
# 247     PIM1   Human      CHEMBL2147      1209     2052
# 248     PLK1   Human      CHEMBL3024       575     1542
# 249    PPARA   Human       CHEMBL239      1884     2755
# 250    PPARA     Rat      CHEMBL2129        53       91
# 251    PPARG   Human   CHEMBL2111394        30       30
# 252    PPARG   Human       CHEMBL235      2377     3774
# 253    PPARG     Rat      CHEMBL4797        16       23
# 254   PRKAA1   Human   CHEMBL2111345         4        7
# 255   PRKAA1   Human      CHEMBL4045       293      967
# 256   PRKAA1     Rat      CHEMBL4533         1        1
# 257   PRKAA2   Human      CHEMBL2116        17       82
# 258   PRKAA2   Human   CHEMBL3038455        14       15
# 259   PRKAA2     Rat      CHEMBL4637         1        4
# 260    PRKCA   Human       CHEMBL299       658     1839
# 261    PRKCA     Rat      CHEMBL2855         6        9
# 262    PRKG1   Human      CHEMBL4273       142      588
# 263    PTGS2   Human       CHEMBL230      2153     4005
# 264    PTGS2     Rat      CHEMBL2977        33       41
# 265     PTK2   Human      CHEMBL2695       450     1237
# 266    QRFPR   Human      CHEMBL5852        25       30
# 267    ROCK1   Human      CHEMBL3231       884     1573
# 268    ROCK1     Rat      CHEMBL5509         2        2
# 269    ROCK2   Human      CHEMBL2973      1042     1637
# 270    ROCK2     Rat      CHEMBL5490         8       13
# 271    SCN5A   Human      CHEMBL1980       191      439
# 272  SLC10A1   Human      CHEMBL5287        12       14
# 273  SLC10A1     Rat      CHEMBL4847         2        2
# 274  SLC10A2   Human      CHEMBL2778       205      235
# 275  SLC10A2     Rat   CHEMBL2073686         5        5
# 276  SLC15A2   Human   CHEMBL1743125        22       78
# 277  SLC15A2     Rat      CHEMBL3325        10       66
# 278  SLC22A1   Human      CHEMBL5685        19       79
# 279  SLC22A1     Rat   CHEMBL2073670        16       43
# 280  SLC22A2   Human   CHEMBL1743122        31       61
# 281  SLC22A2     Rat   CHEMBL1770032        14       39
# 282  SLC22A6   Human   CHEMBL1641347        26       49
# 283  SLC22A6     Rat   CHEMBL1777665        13       47
# 284  SLC22A7   Human   CHEMBL1955711         0        7
# 285  SLC22A7     Rat   CHEMBL2073671         1        9
# 286  SLC29A1   Human      CHEMBL1997       221      274
# 287  SLC29A1     Rat      CHEMBL4604         2        5
# 288  SLC47A1   Human   CHEMBL1743126        32       66
# 289  SLC47A2   Human   CHEMBL1743127        12       37
# 290   SLC6A2   Human       CHEMBL222      2479     3516
# 291   SLC6A2     Rat       CHEMBL304      1211     1419
# 292   SLC6A4   Human       CHEMBL228      3650     4932
# 293   SLC6A4     Rat       CHEMBL313      3288     3654
# 294  SLCO1A2   Human   CHEMBL1743123         0        1
# 295  SLCO1B1   Human   CHEMBL1697668        70       78
# 296  SLCO1B3   Human   CHEMBL1743121        59       67
# 297  SLCO2B1   Human   CHEMBL1743124         5        9
# 298  SLCO2B1     Rat   CHEMBL2073698         2        2
# 299    STK11   Human      CHEMBL5606        14       83
# 300   TBXA2R   Human      CHEMBL2069       908     1190
# 301   TBXA2R     Rat      CHEMBL3156       130      151
# 302       TH   Human      CHEMBL1969         3        5
# 303       TH     Rat      CHEMBL2462         1        1
# 304     TPMT   Human      CHEMBL2500         5       27
# 305   UGT1A1   Human   CHEMBL1287617         0        2
# 306  UGT2B17   Human      CHEMBL4978         0       30
# 307   UGT2B7   Human      CHEMBL4370        40       78
# 308    UTS2R   Human      CHEMBL3764       184      198
# 309    UTS2R     Rat      CHEMBL4921        65       71
# 310      VDR   Human      CHEMBL1977       259    20643
# 311      VDR     Rat      CHEMBL3150        49       58

# %%
# Count targets having thirty or more distint active parent compounds...

{x: len(set(count_by_target.query("species == @x and n_active >= 30")['symbol'].values)) for x in ['Human', 'Rat']}
# Out:
# {'Human': 142, 'Rat': 54}

# %%
# Get symbols (Human only)...

found_targets = set(count_by_target.query("species == 'Human' and n_active >= 30")['symbol'].values)

# %% [markdown]
# ###  Symbol and Species
#
# Aggregate at symbol/species level, _i.e._ merge across ChEMBL targets for a given symbol/species combination.

# %%
count_by_symbol_and_species = pd.read_sql_query("""
select
    a.symbol
  , a.species
  , count(distinct case when a.active = 1 then a.parent_cmpd_chemblid end) as n_active
  , count(distinct a.parent_cmpd_chemblid) as n_total
from
  tt_curve_data_v2 a
where
    a.exclude = 0
and a.nat <= :max_nat
group by
    a.symbol
  , a.species
order by
    a.symbol
  , a.species
""", engine, params={'max_nat': max_nat})

count_by_symbol_and_species.shape
# Out:
# (279, 4)

# %%
count_by_symbol_and_species
# Out:
#       symbol species  n_active  n_total
# 0      ABCB1   Human       784     1249
# 1     ABCB11   Human         1       16
# 2     ABCB11     Rat         8        9
# 3      ABCC2   Human         5       27
# 4      ABCC2     Rat        14       55
# 5      ABCC3   Human         1        1
# 6      ABCC3     Rat         1        4
# 7      ABCC4   Human         8       21
# 8      ABCG2   Human       266      379
# 9       ABL1   Human       978     1828
# 10       ACE   Human       465      653
# 11       ACE     Rat       294      359
# 12      ACHE   Human      2030     4099
# 13      ACHE     Rat       729     1033
# 14     ADCY5   Human        23       83
# 15     ADCY5     Rat        18       22
# 16    ADORA1   Human      3036     4483
# 17    ADORA1     Rat      2270     2957
# 18   ADORA2A   Human      3364     5099
# 19   ADORA2A     Rat      1387     1744
# 20   ADORA2B   Human      1602     2366
# 21   ADORA2B     Rat        37       53
# 22    ADORA3   Human      2951     4365
# 23    ADORA3     Rat       260      379
# 24    ADRA1A   Human      1160     1255
# 25    ADRA1A     Rat       467      528
# 26    ADRA1B   Human       908     1108
# 27    ADRA1B     Rat       199      933
# 28    ADRA1D   Human       862     1678
# 29    ADRA1D     Rat       511     1282
# 30    ADRA2A   Human       660     1481
# 31    ADRA2A     Rat        41       77
# 32    ADRA2B   Human       384     1118
# 33    ADRA2B     Rat        47       50
# 34    ADRA2C   Human       499     1253
# 35    ADRA2C     Rat         4        4
# 36     ADRB1   Human      1131     2225
# 37     ADRB1     Rat        90      183
# 38     ADRB2   Human      1290     3789
# 39     ADRB2     Rat        41       65
# 40     ADRB3   Human      1356     2208
# 41     ADRB3     Rat        33       38
# 42    ADRBK1   Human        75      121
# 43     AGTR1   Human       567     1001
# 44     AGTR1     Rat        73      150
# 45       AHR   Human       172      428
# 46       AHR     Rat         1        1
# 47      AKT1   Human      1289     2279
# 48      AKT2   Human       525     1279
# 49      AKT3   Human       313     1055
# 50     APLNR   Human        15       91
# 51        AR   Human      1432     2335
# 52        AR     Rat       304     1181
# 53     AURKA   Human      1766     2888
# 54     AURKB   Human      1479     2182
# 55     AURKC   Human        77      131
# 56    AVPR1A   Human       550     1462
# 57    AVPR1A     Rat       251      280
# 58    AVPR1B   Human       229      669
# 59    AVPR1B     Rat        27       31
# 60    BDKRB1   Human       659      716
# 61    BDKRB1     Rat        34       34
# 62    BDKRB2   Human       348     1216
# 63    BDKRB2     Rat        20       46
# 64      BRAF   Human       544      764
# 65       CA2   Human      3746     5000
# 66       CA2     Rat         1        1
# 67   CACNA1C   Human        62      119
# 68   CACNA1C     Rat        81      110
# 69   CACNA1G   Human       250      291
# 70   CACNA1H   Human        73     1062
# 71     CALCR   Human         1      791
# 72    CALCRL   Human       616      648
# 73    CALCRL     Rat         7        9
# 74    CAMK2A   Human        89      392
# 75      CDK2   Human      3175     5105
# 76      CDK4   Human      1035     1590
# 77     CHRM1   Human      1323     2588
# 78     CHRM1     Rat      1212     1685
# 79     CHRM2   Human      1238     2290
# 80     CHRM2     Rat       405      505
# 81     CHRM3   Human      1254     2288
# 82     CHRM3     Rat       165      247
# 83     CHRM4   Human       473     1430
# 84     CHRM4     Rat        40       76
# 85    CHRNA1   Human        58      164
# 86    CHRNA4   Human       831     1131
# 87    CHRNA4     Rat      1344     1681
# 88    CYP1A1   Human        99      120
# 89    CYP1A1     Rat        12       25
# 90    CYP1A2   Human      6174    18307
# 91    CYP1A2     Rat         0        1
# 92    CYP2A6   Human        81      967
# 93    CYP2B6   Human        40      194
# 94   CYP2C19   Human      6455    18313
# 95    CYP2C8   Human        68      206
# 96    CYP2C9   Human      5763    18939
# 97    CYP2D6   Human      4180    20053
# 98    CYP2E1   Human        21      884
# 99    CYP2E1     Rat         4       17
# 100   CYP3A4   Human      7779    22706
# 101   CYP3A5   Human        12       31
# 102     DMPK   Human        25       90
# 103     DPYD   Human         6        6
# 104     DRD1   Human       739     2065
# 105     DRD1     Rat       601      973
# 106     DRD2   Human      4155     6054
# 107     DRD2     Rat      3493     4447
# 108     DRD4   Human      1792     2802
# 109     DRD4     Rat       125      134
# 110    EDNRA   Human      1201     2085
# 111    EDNRA     Rat       770      865
# 112    EDNRB   Human       802     1178
# 113    EDNRB     Rat       111      188
# 114     EGFR   Human      3509     6354
# 115    ERBB2   Human      1304     3061
# 116    ERBB2     Rat        13       13
# 117     ESR1   Human      1673     3770
# 118     ESR1     Rat        47       50
# 119     ESR2   Human      1651     3028
# 120     ESR2     Rat        43       48
# 121       F2   Human      3755     6041
# 122       F2     Rat        10       13
# 123     FLT1   Human       915     2516
# 124     FLT4   Human       536      994
# 125     GCGR   Human       697      789
# 126     GCGR     Rat        18       18
# 127     GHSR   Human      1106     1211
# 128     GHSR     Rat        38       55
# 129    GRIN1   Human       275      332
# 130    GRIN1     Rat       727     1089
# 131     GRK5   Human       132      400
# 132    GSK3A   Human       658     1356
# 133    GSK3B   Human      2239     3350
# 134    GSK3B     Rat        17       17
# 135    GSTM1   Human         3       15
# 136    GSTP1   Human        40       83
# 137    GSTT1     Rat         1        1
# 138     HCN2   Human         1        1
# 139     HCN4   Human        22       42
# 140    HNF4A   Human         7      236
# 141     HRH1   Human       918     1917
# 142     HRH1     Rat       114      154
# 143     HRH2   Human       245     1121
# 144     HRH2     Rat         5       37
# 145     HRH3   Human      2928     3141
# 146     HRH3     Rat      1306     1381
# 147    HTR1B   Human       924     1096
# 148    HTR1B     Rat       284     1162
# 149    HTR2A   Human      2388     3386
# 150    HTR2A     Rat      1378     1683
# 151    HTR2B   Human       953     1793
# 152    HTR2B     Rat       130      135
# 153    HTR2C   Human      2183     3387
# 154    HTR2C     Rat       457      608
# 155     HTR4   Human       329      365
# 156     HTR4     Rat       162      245
# 157     HTR7   Human      1130     1346
# 158     HTR7     Rat       298      331
# 159     JAK2   Human      1343     2181
# 160    KCNA4   Human         4        5
# 161    KCNA5   Human       521      602
# 162    KCNC1   Human         0        4
# 163    KCNC1     Rat         1        2
# 164    KCND2     Rat         4        7
# 165    KCND3   Human         3        4
# 166    KCNH2   Human      3798     8084
# 167   KCNJ11   Human        84      109
# 168    KCNJ2   Human         0        3
# 169    KCNK3   Human         1        1
# 170    KCNQ1   Human        54      122
# 171      KDR   Human      4505     6209
# 172      KIT   Human       800     1464
# 173      LTK   Human       185      402
# 174     MAOA   Human       714     2294
# 175     MAOA     Rat       529      986
# 176   MAP3K5   Human        51      170
# 177    MAPK1   Human      3847    15251
# 178    MAPK1     Rat        11       28
# 179    MAPK3   Human        56      989
# 180     MLNR   Human       247      286
# 181   MTNR1A   Human       678      767
# 182   MTNR1B   Human       610      645
# 183   MTNR1B     Rat         1        1
# 184     MTOR   Human      1351     4748
# 185     MTOR     Rat        30       30
# 186     NAT1   Human        27       48
# 187   NFE2L2   Human         4    84881
# 188     NOS3   Human       290      772
# 189     NOS3     Rat         6        8
# 190     NPR1   Human         2        2
# 191    NPY1R   Human       575     1693
# 192    NPY1R     Rat         2        4
# 193    NR0B2   Human         4        4
# 194    NR1H2   Human       567      729
# 195    NR1H3   Human       538      664
# 196    NR1H4   Human       503     1132
# 197    NR1I2   Human       122      379
# 198    NR1I2     Rat         0      398
# 199    NR1I3   Human         0        3
# 200    NR3C1   Human      1860     3328
# 201    NR3C1     Rat       107      132
# 202    NR5A2   Human        47      292
# 203    OPRD1   Human      2534     4622
# 204    OPRD1     Rat      1182     1443
# 205    OPRK1   Human      2972     4475
# 206    OPRK1     Rat       170      244
# 207    OPRM1   Human      2810     4838
# 208    OPRM1     Rat      1748     2020
# 209    PDE3A   Human       181      341
# 210    PDE3B   Human        95      118
# 211   PDGFRA   Human       369      653
# 212   PDGFRB   Human       831     1380
# 213   PDGFRB     Rat        17       22
# 214    PDPK1   Human       376     1089
# 215   PIK3CA   Human      2178     2768
# 216   PIK3CG   Human      1118     1475
# 217     PIM1   Human      1209     2052
# 218     PLK1   Human       575     1542
# 219    PPARA   Human      1884     2755
# 220    PPARA     Rat        53       91
# 221    PPARG   Human      2404     3801
# 222    PPARG     Rat        16       23
# 223   PRKAA1   Human       297      974
# 224   PRKAA1     Rat         1        1
# 225   PRKAA2   Human        31       96
# 226   PRKAA2     Rat         1        4
# 227    PRKCA   Human       658     1839
# 228    PRKCA     Rat         6        9
# 229    PRKG1   Human       142      588
# 230    PTGS2   Human      2153     4005
# 231    PTGS2     Rat        33       41
# 232     PTK2   Human       450     1237
# 233    QRFPR   Human        25       30
# 234    ROCK1   Human       884     1573
# 235    ROCK1     Rat         2        2
# 236    ROCK2   Human      1042     1637
# 237    ROCK2     Rat         8       13
# 238    SCN5A   Human       191      439
# 239  SLC10A1   Human        12       14
# 240  SLC10A1     Rat         2        2
# 241  SLC10A2   Human       205      235
# 242  SLC10A2     Rat         5        5
# 243  SLC15A2   Human        22       78
# 244  SLC15A2     Rat        10       66
# 245  SLC22A1   Human        19       79
# 246  SLC22A1     Rat        16       43
# 247  SLC22A2   Human        31       61
# 248  SLC22A2     Rat        14       39
# 249  SLC22A6   Human        26       49
# 250  SLC22A6     Rat        13       47
# 251  SLC22A7   Human         0        7
# 252  SLC22A7     Rat         1        9
# 253  SLC29A1   Human       221      274
# 254  SLC29A1     Rat         2        5
# 255  SLC47A1   Human        32       66
# 256  SLC47A2   Human        12       37
# 257   SLC6A2   Human      2479     3516
# 258   SLC6A2     Rat      1211     1419
# 259   SLC6A4   Human      3650     4932
# 260   SLC6A4     Rat      3288     3654
# 261  SLCO1A2   Human         0        1
# 262  SLCO1B1   Human        70       78
# 263  SLCO1B3   Human        59       67
# 264  SLCO2B1   Human         5        9
# 265  SLCO2B1     Rat         2        2
# 266    STK11   Human        14       83
# 267   TBXA2R   Human       908     1190
# 268   TBXA2R     Rat       130      151
# 269       TH   Human         3        5
# 270       TH     Rat         1        1
# 271     TPMT   Human         5       27
# 272   UGT1A1   Human         0        2
# 273  UGT2B17   Human         0       30
# 274   UGT2B7   Human        40       78
# 275    UTS2R   Human       184      198
# 276    UTS2R     Rat        65       71
# 277      VDR   Human       259    20643
# 278      VDR     Rat        49       58

# %%
# Count symbols (for species) having thirty or more distint active parent compounds...

{x: len(set(count_by_symbol_and_species.query("species == @x and n_active >= 30")['symbol'].values)) for x in ['Human', 'Rat']}
# Out:
# {'Human': 143, 'Rat': 54}

# %%
# Get symbols (Human only)...

found_symbol_and_species = set(count_by_symbol_and_species.query("species == 'Human' and n_active >= 30")['symbol'].values)

# %%
# Symbols 'recovered' by merging targets (Human only)...

recovered_symbol_and_species = set(found_symbol_and_species).difference(found_targets)

len(recovered_symbol_and_species)
# Out:
# 1

# %%
count_by_symbol_and_species.query("symbol in @recovered_symbol_and_species and species == 'Human'")
# Out:
#      symbol species  n_active  n_total
# 225  PRKAA2   Human        31       96

# %%
count_by_target.query("symbol in @recovered_symbol_and_species and species == 'Human'")
# Out:
#      symbol species target_chemblid  n_active  n_total
# 257  PRKAA2   Human      CHEMBL2116        17       82
# 258  PRKAA2   Human   CHEMBL3038455        14       15

# %% [markdown]
# ### Symbol only
#
# Aggregate at symbol level, _i.e._ merge across ChEMBL target and species for a given symbol.

# %%
count_by_symbol = pd.read_sql_query("""
select
    a.symbol
  , count(distinct case when a.active = 1 then a.parent_cmpd_chemblid end) as n_active
  , count(distinct a.parent_cmpd_chemblid) as n_total
from
  tt_curve_data_v2 a
where
    a.exclude = 0
and a.nat <= :max_nat
group by
    a.symbol
order by
    a.symbol
""", engine, params={'max_nat': max_nat})

count_by_symbol.shape
# Out:
# (184, 3)

# %%
count_by_symbol
# Out:
#       symbol  n_active  n_total
# 0      ABCB1       784     1249
# 1     ABCB11         9       22
# 2      ABCC2        17       79
# 3      ABCC3         2        5
# 4      ABCC4         8       21
# 5      ABCG2       266      379
# 6       ABL1       978     1828
# 7        ACE       742      992
# 8       ACHE      2550     4877
# 9      ADCY5        41      105
# 10    ADORA1      5093     7163
# 11   ADORA2A      4453     6485
# 12   ADORA2B      1615     2386
# 13    ADORA3      3107     4607
# 14    ADRA1A      1536     1690
# 15    ADRA1B      1059     1991
# 16    ADRA1D      1262     2119
# 17    ADRA2A       683     1539
# 18    ADRA2B       419     1155
# 19    ADRA2C       500     1254
# 20     ADRB1      1213     2394
# 21     ADRB2      1317     3836
# 22     ADRB3      1374     2231
# 23    ADRBK1        75      121
# 24     AGTR1       631     1141
# 25       AHR       173      429
# 26      AKT1      1289     2279
# 27      AKT2       525     1279
# 28      AKT3       313     1055
# 29     APLNR        15       91
# 30        AR      1693     3374
# 31     AURKA      1766     2888
# 32     AURKB      1479     2182
# 33     AURKC        77      131
# 34    AVPR1A       744     1676
# 35    AVPR1B       231      671
# 36    BDKRB1       666      723
# 37    BDKRB2       358     1252
# 38      BRAF       544      764
# 39       CA2      3746     5000
# 40   CACNA1C       133      219
# 41   CACNA1G       250      291
# 42   CACNA1H        73     1062
# 43     CALCR         1      791
# 44    CALCRL       616      648
# 45    CAMK2A        89      392
# 46      CDK2      3175     5105
# 47      CDK4      1035     1590
# 48     CHRM1      2444     4086
# 49     CHRM2      1586     2721
# 50     CHRM3      1399     2503
# 51     CHRM4       497     1482
# 52    CHRNA1        58      164
# 53    CHRNA4      1885     2484
# 54    CYP1A1       111      145
# 55    CYP1A2      6174    18308
# 56    CYP2A6        81      967
# 57    CYP2B6        40      194
# 58   CYP2C19      6455    18313
# 59    CYP2C8        68      206
# 60    CYP2C9      5763    18939
# 61    CYP2D6      4180    20053
# 62    CYP2E1        25      901
# 63    CYP3A4      7779    22706
# 64    CYP3A5        12       31
# 65      DMPK        25       90
# 66      DPYD         6        6
# 67      DRD1      1263     2933
# 68      DRD2      7293    10058
# 69      DRD4      1893     2911
# 70     EDNRA      1864     2832
# 71     EDNRB       892     1338
# 72      EGFR      3509     6354
# 73     ERBB2      1308     3063
# 74      ESR1      1702     3800
# 75      ESR2      1671     3052
# 76        F2      3764     6051
# 77      FLT1       915     2516
# 78      FLT4       536      994
# 79      GCGR       698      790
# 80      GHSR      1138     1260
# 81     GRIN1       989     1408
# 82      GRK5       132      400
# 83     GSK3A       658     1356
# 84     GSK3B      2245     3350
# 85     GSTM1         3       15
# 86     GSTP1        40       83
# 87     GSTT1         1        1
# 88      HCN2         1        1
# 89      HCN4        22       42
# 90     HNF4A         7      236
# 91      HRH1      1004     2032
# 92      HRH2       249     1154
# 93      HRH3      3332     3571
# 94     HTR1B      1177     2219
# 95     HTR2A      3613     4901
# 96     HTR2B      1068     1913
# 97     HTR2C      2591     3937
# 98      HTR4       478      597
# 99      HTR7      1380     1629
# 100     JAK2      1343     2181
# 101    KCNA4         4        5
# 102    KCNA5       521      602
# 103    KCNC1         1        6
# 104    KCND2         4        7
# 105    KCND3         3        4
# 106    KCNH2      3798     8084
# 107   KCNJ11        84      109
# 108    KCNJ2         0        3
# 109    KCNK3         1        1
# 110    KCNQ1        54      122
# 111      KDR      4505     6209
# 112      KIT       800     1464
# 113      LTK       185      402
# 114     MAOA      1208     3217
# 115   MAP3K5        51      170
# 116    MAPK1      3858    15279
# 117    MAPK3        56      989
# 118     MLNR       247      286
# 119   MTNR1A       678      767
# 120   MTNR1B       610      645
# 121     MTOR      1379     4776
# 122     NAT1        27       48
# 123   NFE2L2         4    84881
# 124     NOS3       291      772
# 125     NPR1         2        2
# 126    NPY1R       575     1694
# 127    NR0B2         4        4
# 128    NR1H2       567      729
# 129    NR1H3       538      664
# 130    NR1H4       503     1132
# 131    NR1I2       122      772
# 132    NR1I3         0        3
# 133    NR3C1      1897     3379
# 134    NR5A2        47      292
# 135    OPRD1      3577     5882
# 136    OPRK1      3113     4677
# 137    OPRM1      4435     6699
# 138    PDE3A       181      341
# 139    PDE3B        95      118
# 140   PDGFRA       369      653
# 141   PDGFRB       847     1401
# 142    PDPK1       376     1089
# 143   PIK3CA      2178     2768
# 144   PIK3CG      1118     1475
# 145     PIM1      1209     2052
# 146     PLK1       575     1542
# 147    PPARA      1928     2830
# 148    PPARG      2417     3819
# 149   PRKAA1       298      975
# 150   PRKAA2        32       99
# 151    PRKCA       661     1845
# 152    PRKG1       142      588
# 153    PTGS2      2182     4041
# 154     PTK2       450     1237
# 155    QRFPR        25       30
# 156    ROCK1       885     1574
# 157    ROCK2      1042     1637
# 158    SCN5A       191      439
# 159  SLC10A1        13       15
# 160  SLC10A2       205      235
# 161  SLC15A2        30      117
# 162  SLC22A1        31      101
# 163  SLC22A2        41       80
# 164  SLC22A6        35       73
# 165  SLC22A7         1        9
# 166  SLC29A1       223      278
# 167  SLC47A1        32       66
# 168  SLC47A2        12       37
# 169   SLC6A2      3622     4841
# 170   SLC6A4      6438     8008
# 171  SLCO1A2         0        1
# 172  SLCO1B1        70       78
# 173  SLCO1B3        59       67
# 174  SLCO2B1         7       11
# 175    STK11        14       83
# 176   TBXA2R       958     1251
# 177       TH         3        5
# 178     TPMT         5       27
# 179   UGT1A1         0        2
# 180  UGT2B17         0       30
# 181   UGT2B7        40       78
# 182    UTS2R       190      209
# 183      VDR       303    20690

# %%
# Get and count symbols having thirty or more distint active parent compounds...

found_symbol = set(count_by_symbol.query("n_active >= 30")['symbol'].values)

len(found_symbol)
# Out:
# 147

# %%
# Extra symbols 'recovered' by merging targets *and* species...

recovered_symbol =  set(found_symbol).difference(found_targets).difference(found_symbol_and_species)

len(recovered_symbol)
# Out:
# 4

# %%
count_by_symbol.query("symbol in @recovered_symbol")
# Out:
#       symbol  n_active  n_total
# 9      ADCY5        41      105
# 161  SLC15A2        30      117
# 162  SLC22A1        31      101
# 164  SLC22A6        35       73

# %%
count_by_target.query("symbol in @recovered_symbol")
# Out:
#       symbol species target_chemblid  n_active  n_total
# 14     ADCY5   Human      CHEMBL3189        23       83
# 15     ADCY5     Rat      CHEMBL2880        18       22
# 276  SLC15A2   Human   CHEMBL1743125        22       78
# 277  SLC15A2     Rat      CHEMBL3325        10       66
# 278  SLC22A1   Human      CHEMBL5685        19       79
# 279  SLC22A1     Rat   CHEMBL2073670        16       43
# 282  SLC22A6   Human   CHEMBL1641347        26       49
# 283  SLC22A6     Rat   CHEMBL1777665        13       47

# %% [markdown]
# ## What targets have been lost?
#
# What is lost when aggregating at the symbol/species level after filtering by activity and AMW?

# %%
# Consider only Human targets passing distinct active compound threshold...

lost = set(targets.symbol).difference(found_symbol_and_species)

len(lost)
# Out:
# 52

# %%
# HTML(targets.query("symbol in @lost").to_html())

# %% [markdown]
# ### In terms of original 'targets' and the tables they appear in
#
# The 'lost' targets mainly seem to be...
#
# * Ion channels
# * Transporters
# * Xenobiotic metabolising enzymes

# %%
symbols = pd.read_pickle('unique_symbols.pkl')

symbols.head()
# Out:
#         symbol                                            approved_name                                                                                targets
# symbol
# ABCB1    ABCB1   ATP-binding cassette, sub-family B (MDR/TAP), member 1   ((MDR1, 7), (MDR1, 8), (ATP-binding cassette, sub-family B (MDR/TAP), member 1, 11))
# ABCB11  ABCB11  ATP-binding cassette, sub-family B (MDR/TAP), member 11                                                      ((BSEP, 6), (BSEP, 7), (BSEP, 8))
# ABCB4    ABCB4   ATP-binding cassette, sub-family B (MDR/TAP), member 4                                                                 ((MDR3, 7), (MDR3, 8))
# ABCC2    ABCC2  ATP-binding cassette, sub-family C (CFTR/MRP), member 2  ((MRP2, 7), (MRP2, 8), (ATP-binding cassette, sub-family C (CFTR/MRP), member 2, 11))
# ABCC3    ABCC3  ATP-binding cassette, sub-family C (CFTR/MRP), member 3                                                                 ((MRP3, 7), (MRP3, 8))

# %%
def f(key, group):
    
    symbols = group['symbol'].values
        
    return {'target': key, 'symbols': symbols, 'count': len(symbols)}
    
pd.DataFrame([f(x, y) for x, y in sorted(symbols.loc[lost].groupby('targets'), key=lambda x: float(x[0][0][1]))], columns=['target', 'symbols', 'count'])
# Out:
#                                                                                            target         symbols  count
# 0    ((Potassium voltage-gated channel KQT-like member 1 and minimal potassium channel MinK, 1),)         [KCNE1]      1
# 1                                                                                   ((ANF, 2.2),)          [NPR1]      1
# 2                                                                                   ((APJ, 2.2),)         [APLNR]      1
# 3                                                                                 ((CGRP1, 2.2),)         [CALCR]      1
# 4                                                                                ((GPR103, 2.2),)         [QRFPR]      1
# 5                                                                        ((adenylyl cyclase, 3),)         [ADCY5]      1
# 6                                                                    ((tyrosine hydroxylase, 3),)            [TH]      1
# 7                                                                                     ((IK1, 4),)         [KCNJ2]      1
# 8                                                                                   ((IKAch, 4),)  [KCNJ3, KCNJ5]      2
# 9                                                                                     ((IKP, 4),)         [KCNK3]      1
# 10                                                                                   ((IKur, 4),)         [KCNC1]      1
# 11                                                                                     ((If, 4),)    [HCN2, HCN4]      2
# 12                                                                                  ((Ito,f, 4),)  [KCND3, KCND2]      2
# 13                                                                                  ((Ito,s, 4),)         [KCNA4]      1
# 14                                                                                   ((DMPK, 5),)          [DMPK]      1
# 15                                                                                   ((LKB1, 5),)         [STK11]      1
# 16                                                              ((BSEP, 6), (BSEP, 7), (BSEP, 8))        [ABCB11]      1
# 17                                                              ((NTCP, 6), (NTCP, 7), (NTCP, 8))       [SLC10A1]      1
# 18                                                                  ((OSTα/OSTβ, 6), (OSTα/β, 8))        [SLC51A]      1
# 19                                                                         ((MDR3, 7), (MDR3, 8))         [ABCB4]      1
# 20          ((MRP2, 7), (MRP2, 8), (ATP-binding cassette, sub-family C (CFTR/MRP), member 2, 11))         [ABCC2]      1
# 21                                                                         ((MRP3, 7), (MRP3, 8))         [ABCC3]      1
# 22                                                                         ((MRP4, 7), (MRP4, 8))         [ABCC4]      1
# 23                                                                     ((OATPs, 7), (OATP1A2, 8))       [SLCO1A2]      1
# 24                                                                     ((OATPs, 7), (OATP2B1, 8))       [SLCO2B1]      1
# 25                                                                         ((OATs, 7), (OAT2, 8))       [SLC22A7]      1
# 26                                                                         ((OATs, 7), (OAT7, 8))       [SLC22A9]      1
# 27  ((OCTs, 7), (OCT1, 8), (solute carrier family 22 (organic cation transporter), member 1, 11))       [SLC22A1]      1
# 28                                                                                 ((ENT1/2, 8),)       [SLC29A2]      1
# 29                                                                                ((MATE2-K, 8),)       [SLC47A2]      1
# 30                                                                                   ((MRP6, 8),)         [ABCC6]      1
# 31                                                                                    ((CAR, 9),)         [NR1I3]      1
# 32                                                                                  ((HNF4α, 9),)         [HNF4A]      1
# 33                                                                                   ((Nrf2, 9),)        [NFE2L2]      1
# 34                                                                                    ((SHP, 9),)         [NR0B2]      1
# 35                                 ((N-acetyltransferase 1 (arylamine N-acetyltransferase), 11),)          [NAT1]      1
# 36                                 ((N-acetyltransferase 2 (arylamine N-acetyltransferase), 11),)          [NAT2]      1
# 37                                  ((UDP glucuronosyltransferase 1 family, polypeptide A1, 11),)        [UGT1A1]      1
# 38                                 ((UDP glucuronosyltransferase 2 family, polypeptide B15, 11),)       [UGT2B15]      1
# 39                                 ((UDP glucuronosyltransferase 2 family, polypeptide B17, 11),)       [UGT2B17]      1
# 40                                 ((cytochrome P450, family 2, subfamily E, polypeptide 1, 11),)        [CYP2E1]      1
# 41                                 ((cytochrome P450, family 3, subfamily A, polypeptide 5, 11),)        [CYP3A5]      1
# 42                                                       ((dihydropyrimidine dehydrogenase, 11),)          [DPYD]      1
# 43                                                          ((glutathione S-transferase M1, 11),)         [GSTM1]      1
# 44                                                     ((glutathione S-transferase theta 1, 11),)         [GSTT1]      1
# 45                           ((solute carrier family 15 (H+/peptide transporter), member 2, 11),)       [SLC15A2]      1
# 46                        ((solute carrier family 22 (organic anion transporter), member 6, 11),)       [SLC22A6]      1
# 47                   ((sulfotransferase family, cytosolic, 1A, phenol-preferring, member 1, 11),)       [SULT1A1]      1
# 48                                                        ((thiopurine S-methyltransferase, 11),)          [TPMT]      1

# %%
symbols.query("symbol in @lost")
# Out:
#           symbol                                                              approved_name                                                                                        targets
# symbol
# ABCB11    ABCB11                    ATP-binding cassette, sub-family B (MDR/TAP), member 11                                                              ((BSEP, 6), (BSEP, 7), (BSEP, 8))
# ABCB4      ABCB4                     ATP-binding cassette, sub-family B (MDR/TAP), member 4                                                                         ((MDR3, 7), (MDR3, 8))
# ABCC2      ABCC2                    ATP-binding cassette, sub-family C (CFTR/MRP), member 2          ((MRP2, 7), (MRP2, 8), (ATP-binding cassette, sub-family C (CFTR/MRP), member 2, 11))
# ABCC3      ABCC3                    ATP-binding cassette, sub-family C (CFTR/MRP), member 3                                                                         ((MRP3, 7), (MRP3, 8))
# ABCC4      ABCC4                    ATP-binding cassette, sub-family C (CFTR/MRP), member 4                                                                         ((MRP4, 7), (MRP4, 8))
# ABCC6      ABCC6                    ATP-binding cassette, sub-family C (CFTR/MRP), member 6                                                                                   ((MRP6, 8),)
# ADCY5      ADCY5                                                        adenylate cyclase 5                                                                       ((adenylyl cyclase, 3),)
# APLNR      APLNR                                                            apelin receptor                                                                                  ((APJ, 2.2),)
# CALCR      CALCR                                                        calcitonin receptor                                                                                ((CGRP1, 2.2),)
# CYP2E1    CYP2E1                      cytochrome P450, family 2, subfamily E, polypeptide 1                                 ((cytochrome P450, family 2, subfamily E, polypeptide 1, 11),)
# CYP3A5    CYP3A5                      cytochrome P450, family 3, subfamily A, polypeptide 5                                 ((cytochrome P450, family 3, subfamily A, polypeptide 5, 11),)
# DMPK        DMPK                                        dystrophia myotonica-protein kinase                                                                                   ((DMPK, 5),)
# DPYD        DPYD                                            dihydropyrimidine dehydrogenase                                                       ((dihydropyrimidine dehydrogenase, 11),)
# GSTM1      GSTM1                                             glutathione S-transferase mu 1                                                          ((glutathione S-transferase M1, 11),)
# GSTT1      GSTT1                                          glutathione S-transferase theta 1                                                     ((glutathione S-transferase theta 1, 11),)
# HCN2        HCN2    hyperpolarization activated cyclic nucleotide gated potassium channel 2                                                                                     ((If, 4),)
# HCN4        HCN4    hyperpolarization activated cyclic nucleotide gated potassium channel 4                                                                                     ((If, 4),)
# HNF4A      HNF4A                                         hepatocyte nuclear factor 4, alpha                                                                                  ((HNF4α, 9),)
# KCNA4      KCNA4      potassium channel, voltage gated shaker related subfamily A, member 4                                                                                  ((Ito,s, 4),)
# KCNC1      KCNC1        potassium channel, voltage gated Shaw related subfamily C, member 1                                                                                   ((IKur, 4),)
# KCND2      KCND2        potassium channel, voltage gated Shal related subfamily D, member 2                                                                                  ((Ito,f, 4),)
# KCND3      KCND3        potassium channel, voltage gated Shal related subfamily D, member 3                                                                                  ((Ito,f, 4),)
# KCNE1      KCNE1     potassium channel, voltage gated subfamily E regulatory beta subunit 1   ((Potassium voltage-gated channel KQT-like member 1 and minimal potassium channel MinK, 1),)
# KCNJ2      KCNJ2               potassium channel, inwardly rectifying subfamily J, member 2                                                                                    ((IK1, 4),)
# KCNJ3      KCNJ3               potassium channel, inwardly rectifying subfamily J, member 3                                                                                  ((IKAch, 4),)
# KCNJ5      KCNJ5               potassium channel, inwardly rectifying subfamily J, member 5                                                                                  ((IKAch, 4),)
# KCNK3      KCNK3                   potassium channel, two pore domain subfamily K, member 3                                                                                    ((IKP, 4),)
# NAT1        NAT1                      N-acetyltransferase 1 (arylamine N-acetyltransferase)                                 ((N-acetyltransferase 1 (arylamine N-acetyltransferase), 11),)
# NAT2        NAT2                      N-acetyltransferase 2 (arylamine N-acetyltransferase)                                 ((N-acetyltransferase 2 (arylamine N-acetyltransferase), 11),)
# NFE2L2    NFE2L2                                         nuclear factor, erythroid 2-like 2                                                                                   ((Nrf2, 9),)
# NPR1        NPR1                                             natriuretic peptide receptor 1                                                                                  ((ANF, 2.2),)
# NR0B2      NR0B2                            nuclear receptor subfamily 0, group B, member 2                                                                                    ((SHP, 9),)
# NR1I3      NR1I3                            nuclear receptor subfamily 1, group I, member 3                                                                                    ((CAR, 9),)
# QRFPR      QRFPR                                  pyroglutamylated RFamide peptide receptor                                                                               ((GPR103, 2.2),)
# SLC10A1  SLC10A1        solute carrier family 10 (sodium/bile acid cotransporter), member 1                                                              ((NTCP, 6), (NTCP, 7), (NTCP, 8))
# SLC15A2  SLC15A2              solute carrier family 15 (oligopeptide transporter), member 2                           ((solute carrier family 15 (H+/peptide transporter), member 2, 11),)
# SLC22A1  SLC22A1            solute carrier family 22 (organic cation transporter), member 1  ((OCTs, 7), (OCT1, 8), (solute carrier family 22 (organic cation transporter), member 1, 11))
# SLC22A6  SLC22A6             solute carrier family 22 (organic anion transporter), member 6                        ((solute carrier family 22 (organic anion transporter), member 6, 11),)
# SLC22A7  SLC22A7             solute carrier family 22 (organic anion transporter), member 7                                                                         ((OATs, 7), (OAT2, 8))
# SLC22A9  SLC22A9             solute carrier family 22 (organic anion transporter), member 9                                                                         ((OATs, 7), (OAT7, 8))
# SLC29A2  SLC29A2  solute carrier family 29 (equilibrative nucleoside transporter), member 2                                                                                 ((ENT1/2, 8),)
# SLC47A2  SLC47A2         solute carrier family 47 (multidrug and toxin extrusion), member 2                                                                                ((MATE2-K, 8),)
# SLC51A    SLC51A                                    solute carrier family 51, alpha subunit                                                                  ((OSTα/OSTβ, 6), (OSTα/β, 8))
# SLCO1A2  SLCO1A2                solute carrier organic anion transporter family, member 1A2                                                                     ((OATPs, 7), (OATP1A2, 8))
# SLCO2B1  SLCO2B1                solute carrier organic anion transporter family, member 2B1                                                                     ((OATPs, 7), (OATP2B1, 8))
# STK11      STK11                                                 serine/threonine kinase 11                                                                                   ((LKB1, 5),)
# SULT1A1  SULT1A1        sulfotransferase family, cytosolic, 1A, phenol-preferring, member 1                   ((sulfotransferase family, cytosolic, 1A, phenol-preferring, member 1, 11),)
# TH            TH                                                       tyrosine hydroxylase                                                                   ((tyrosine hydroxylase, 3),)
# TPMT        TPMT                                             thiopurine S-methyltransferase                                                        ((thiopurine S-methyltransferase, 11),)
# UGT1A1    UGT1A1                       UDP glucuronosyltransferase 1 family, polypeptide A1                                  ((UDP glucuronosyltransferase 1 family, polypeptide A1, 11),)
# UGT2B15  UGT2B15                      UDP glucuronosyltransferase 2 family, polypeptide B15                                 ((UDP glucuronosyltransferase 2 family, polypeptide B15, 11),)
# UGT2B17  UGT2B17                      UDP glucuronosyltransferase 2 family, polypeptide B17                                 ((UDP glucuronosyltransferase 2 family, polypeptide B17, 11),)

# %%
def f(x):
        
    targets = x['targets']
                 
    return pd.DataFrame({'symbol': [x['symbol']]*len(targets), 'table': [y[1] for y in targets]})

subset = symbols.query("symbol in @lost")

tables = pd.concat(f(x) for i, x in subset.iterrows())

tables['table'].value_counts()
# Out:
# 11     16
# 8      15
# 7      11
# 4      10
# 9       4
# 2.2     4
# 6       3
# 5       2
# 3       2
# 1       1
# dtype: int64

# %% [markdown]
# ## Add counts to targets file

# %%
targets = targets.merge(count_by_target[['target_chemblid', 'n_active', 'n_total']], left_on='chembl_id', right_on='target_chemblid', how='left').drop('target_chemblid', axis=1)

targets = targets.merge(count_by_symbol_and_species[['symbol', 'species', 'n_active', 'n_total']], on=['symbol', 'species'], how='left', suffixes=['_tgt', '_ss'])

targets.fillna(0, inplace=True)

targets.shape
# Out:
# (377, 15)

# %%
targets.query("exclude == 0").shape
# Out:
# (358, 15)

# %% [markdown]
# ### Save/restore
#
# File now includes per-target counts.

# %%
# backup_file('chembl_targets.pkl')

targets.to_pickle('chembl_targets.pkl')

# %%
# targets = pd.read_pickle('chembl_targets.pkl')

# targets.shape
